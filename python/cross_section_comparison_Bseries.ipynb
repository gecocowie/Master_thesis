# %% [markdown]
# # B series cross section comparison
#
# Compare runs of the Bseries tubes from the 18-08.2020. Multiple drifters are deployed from each cross section.
#
# procedure:
#
# 1. Find beginning of deployment by running cpd on pressure data (pressure is more reliable than acc because the pressure doese not increase before hitting the water)
# 2. Cut datasets to the first cp detected
#
# ## Potential sections that were filmed at least once:
# A5-A1 8 videos
#
# A6-A1 5
#
# A7-1 1
#
# A8-A1 2 Only one analysed til now
#
# A13-A1 1
#
# A14-A1 1
#
# A15-A1 1

# %% [markdown]
# # Load channel features

# %% [markdown]
# # Cross sections A5-A1

# %%
# %run B_series_functions.ipynb
common_path_A5 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A5_A1/"
B10_A5_path = common_path_A5+'B100818144137.csv'
B14_A5_path = common_path_A5+'B140818144102.csv'
B17_A5_path = common_path_A5+'B170818144158.csv'
B56_A5_path = common_path_A5+'B560818144115.csv'
B75_A5_path = common_path_A5+'B750818144132.csv'
B79_A5_path = common_path_A5+'B790818144150.csv'
B80_A5_path = common_path_A5+'B800818144146.csv'
B82_A5_path = common_path_A5+'B820818134146.csv'
B85_A5_path = common_path_A5+'B850818144158.csv'
B86_A5_path = common_path_A5+'B860818144137.csv'
#cross_section_comp(B10_A5_path,"B10 A5")
#cross_section_comp(filepath,name,model,width,jump,dim,sigma):
model_A5= "ar"
width_A5 = 100
jump_A5 = 10
dim_A5 = 5
sigma_A5 = 0.7
params_A5 = [0,2]
data_vis = "on"
bkps_vis = "off"#"on"
#A5_data, A5_lp,A5_bkps = cross_section_comp(B14_A5_path,"B14 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=0)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B17_A5_path,"B17 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=10)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B56_A5_path,"B56 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=15)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B75_A5_path,"B75 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=20)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B79_A5_path,"B79 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=30)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B80_A5_path,"B80 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=40)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B82_A5_path,"B82 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=50)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B85_A5_path,"B85 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=60)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B86_A5_path,"B86 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=70)

# %% [markdown]
# # A13 - A1

# %%
# %run B_series_functions.ipynb
file_list_A13 = ['B140818162018.csv','B330818161829.csv','B550818161744.csv','B650818161823.csv','B740818161829.csv','B750818161826.csv','B790818161851.csv','B800818161843.csv','B860818161826.csv']
#'B830818161850.csv'garbage file
#'B140818162018.csv', incomplete

common_path_A13 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A13_A1/"
model_A13= "ar"
width_A13 = 100
jump_A13 = 10
dim_A13 = 5
sigma_A13 = 1
params_A13 = [0,2]
data_vis = "off"
bkps_vis = "off"#"on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A13/"

for i in range(len(file_list_A13)):
    drifter_id = file_list_A13[i][0:3]
    path_A13 = common_path_A13 + file_list_A13[i]
    A13_data, A13_lp,A13_bkps,A13_lp_mean = cross_section_comp(path_A13,drifter_id,model_A13,width_A13,jump_A13,dim_A13,sigma_A13,params_A13,data_vis,bkps_vis)
    
    saved_data = pd.DataFrame(A13_lp_mean)        
    #saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A13_A1/B140818162018
# /A13_A1/B330818161829
# /A13_A1/B550818161744
# /A13_A1/B650818161823
# /A13_A1/B740818161829
# /A13_A1/B750818161826
# /A13_A1/B790818161851
# /A13_A1/B800818161843
# /A13_A1/B860818161826

# %% [markdown]
# # Cross section A14 - A1

# %%
# %run B_series_functions.ipynb 
"""B56 A14 A1"""
A14_start = 12990#12729#B56_bkps[0]#12729
A14_end = 27149
time_A14 = time_array(A14_start,A14_end)
A14_vcp = np.array([0.0,1.6,2.5,3.3,6.0,7.5,8.2,10.2,13.3,14.1,15.1,21.1,22.4,23.4,24.2,26.1,28.8,33.4,35.0,36.0,36.1,38.3,42.4,46.1,47.4,49.1,58.4,59.2,59.9,63.8,65.5,73.5,77.4,82.1,87.1,89.0,91.6,93.2,98.6,105.5,111.5,116.4,117.5,120.2,121.8,133.1,134.6,135.7,140.0])
A14_vcp_idx = index_finder(A14_vcp,time_A14,A14_start)-A14_start
A14_meanders = np.array([1.0,9.4,11.7,14.5,33.1,34.0,37.7,38.4,41.5,42.4,46.0,47.7,48.9,57.7,62.7,64.5,65.8,66.9,72.9,74.9,80.4,87.7,90.3,92.0,93.7,104.5,110.6,112.0,117.9,124.2,137.0])
A14_meanders_idx = index_finder(A14_meanders,time_A14,A14_start)-A14_start
"""Load B56 A14 start stop"""
B56_A14_excel_sheet_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/drifter_videos/2020/Video_features_A14_B56_reanalysed.xlsx"
B56_A14_SS = pd.read_excel(B56_A14_excel_sheet_path,header = 8)
B56_A14_HF_start = B56_A14_SS["Start_corr"]
B56_A14_HF_stop = B56_A14_SS["Stop_corr"]

# %%
# %run B_series_functions.ipynb

file_list_A14 = ['B130818162912.csv','B170818162956.csv','B560818162851.csv','B780818162912.csv','B820818152908.csv','B840818162908.csv','B850818162932.csv']
#garbage file 'B680818162902.csv'
# incomplete transect B730818162848.csv'
common_path_A14 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A14_A1/"
model_A14= "ar"
width_A14 = 100
jump_A14 = 10
dim_A14 = 5
sigma_A14 = 1.5
params_A14 = [0,1,2,3,4]
data_vis = "on"
bkps_vis = "off"#"on"
save_file = "on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A14/"

# define subplot grid
plt.subplots(nrows=len(file_list_A14), ncols=1, figsize=(10, 12))


plt.rcParams['font.size'] = '12'
#A14_df = pd.DataFrame()
A14_all = []
for i in range(len(file_list_A14)):
    drifter_id = file_list_A14[i][0:3]
    path_A14 = common_path_A14 + file_list_A14[i]
    A14_data, A14_lp,A14_bkps,A14_lp_mean = cross_section_comp(path_A14,drifter_id,model_A14,width_A14,jump_A14,dim_A14,sigma_A14,params_A14,data_vis,bkps_vis)
    
    if drifter_id == "B56":
        #align observed cp with data
        start = A14_bkps[0]-400
        print("B56 start",start,drifter_id)
        end = A14_bkps[-1]
    else:
        start = A14_bkps[0]
        print("start",start,drifter_id)
        end = A14_bkps[-1]
    
    new_A14 = pd.DataFrame(A14_lp_mean[start:end],columns=[drifter_id])
    #A14_df = pd.concat([A14_df,new_A14])
    A14_all.append(A14_lp_mean[start:end])

    if bkps_vis == "on":
        #show ruptures breakpoints
        rpt.show.display(A14_data[:,params_A14], A14_bkps, figsize=(6, 6))
    if data_vis =="on":
        ax = plt.subplot(len(file_list_A14),1,i+1)
        ax.plot(time_array(start,end),A14_lp_mean[start:end],label = drifter_id)#plot wit seconds on x axis
        ax.set_xlim(left=0, right=150)
        #plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x
        ax.set_ylabel('Pressure [dbar]')
        #plt.plot(time_array(start,end),acc_abs[start:end]+k)
        
            
        if(drifter_id == "B56"):
            time_A14 = time_array(start,end)

            A14_HF_start_idx = index_finder(B56_A14_SS["Start_corr"],time_A14,start)-start
            A14_HF_stop_idx = index_finder(B56_A14_HF_stop,time_A14,start)-start


            plt.plot(time_array(start,end)[A14_vcp_idx],np.ones(len(A14_vcp_idx))*A14_lp_mean[A14_vcp_idx+start],marker = "^", color = "y", label = "Hydrologic features",ls = "None")
            #plt.plot(time_array(start,end)[A14_meanders_idx],np.ones(len(A14_meanders_idx))*A14_lp_mean[A14_meanders_idx+start],marker = "*", color = "b", label = "Meanders",ls = "None")
            
            plt.plot(time_A14[A14_HF_start_idx],np.ones(len(A14_HF_start_idx))*A14_lp_mean[A14_HF_start_idx+start],marker = '|',color = 'r',ls = "None",markersize = 30)
            plt.plot(time_A14[A14_HF_stop_idx],np.ones(len(A14_HF_stop_idx))*A14_lp_mean[A14_HF_stop_idx+start],marker = '|',color = 'g',ls = "None",markersize = 25)
        
        if save_file == "on":
            saved_data = pd.DataFrame(A14_lp_mean)
            #saved_data = pd.DataFrame((A14_data[:,0]+A14_data[:,2])/2)
            
            saved_data.to_csv(save_path+drifter_id+".csv")



ax.set_xlabel('Deployment time [s]')
plt.savefig("test")
plt.show()
A14_all = np.array(A14_all,dtype=object)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /A14_A1/B130818162912
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_23811/3489993340.py in <module>
#      34         end = A14_bkps[-1]
#      35     else:
# ---> 36         start = A14_bkps[0]
#      37         print("start",start,drifter_id)
#      38         end = A14_bkps[-1]
#
# TypeError: 'int' object is not subscriptable

# %%
#A5
# %run B_series_functions.ipynb
file_list = [
'B140818144102.csv',
'B170818144158.csv',
'B560818144115.csv',
'B750818144132.csv',
'B790818144150.csv',
'B800818144146.csv',
'B820818134146.csv',
'B850818144158.csv',
'B860818144137.csv',
]

# incomplete transect B730818162848.csv'
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A5_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A5/"
model= "ar"
width = 100
jump = 10
dim = 5
sigma = 1.36
params = [0,1,2]
data_vis = "off"
bkps_vis = "off"#"on"

for i in range(len(file_list)):
    drifter_id = file_list[i][0:3]
    path = common_path + file_list[i]
    data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")

# %% [markdown]
# # A6

# %%
#A6
# %run B_series_functions.ipynb
file_list = ['B130818145050.csv','B330818145101.csv','B550818145016.csv','B650818145108.csv','B680818145111.csv','B730818145100.csv','B740818145120.csv','B780818145129.csv']
#'B780818145129.csv' looks ok but cp detected before deployment
# 'B840818145123.csv' lost but recovered way down
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A6_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A6/"


model= "ar"
width = 100
jump = 10
dim = 5
sigma = 1
params = [0,2]
data_vis = "off"
bkps_vis = "off"#"on"

for i in range(len(file_list)):
    drifter_id = file_list[i][0:3]
    path = common_path + file_list[i]
    data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")

# %% [markdown]
# # A7

# %%
#A7
# %run B_series_functions.ipynb
file_list_A7 =['B140818150819.csv','B170818150927.csv','B560818150827.csv','B680818150844.csv','B730818150836.csv','B780818150905.csv','B790818150923.csv','B820818140909.csv','B830818150926.csv']

#'B780818145129.csv' looks ok but cp detected before deployment
# 'B840818145123.csv' lost but recovered way down
common_path_A7 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A7_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A7/"


model_A7= "ar"
width_A7 = 100
jump_A7 = 10
dim_A7 = 5
sigma_A7 = 1
params_A7 = [0,2,4]
data_vis = "on"
bkps_vis = "off"#"on"


for i in range(len(file_list_A7)):
    k = 1*i
    drifter_id = file_list_A7[i][0:3]
    path_A7 = common_path_A7 + file_list_A7[i]
    A7_data, A7_lp,A7_bkps, A7_lp_mean = cross_section_comp(path_A7,drifter_id,model_A7,width_A7,jump_A7,dim_A7,sigma_A7,params_A7,data_vis,bkps_vis,k)
    saved_data = pd.DataFrame(A7_lp_mean)        
    #saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")

# %% [markdown]
# # Cross sections A8-A1

# %%
# %run B_series_functions.ipynb
common_path_A8 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A8_A1/"

#cross_section_comp(filepath,name):
model_A8= "ar"#"rank"#"linear"
width_A8 = 100
jump_A8 = 10
dim_A8 = 2
sigma_A8 = 1.3
params_A8 = [0,1]#what drifter parameters to use
data_vis = "on"


# %run B_series_functions.ipynb
file_list_A8 = ['B100818151712.csv','B130818151711.csv','B330818151708.csv','B550818151622.csv','B650818151700.csv','B740818151658.csv','B750818151704.csv','B800818151707.csv','B840818151701.csv','B850818151721.csv','B860818151701.csv']
#'B830818161850.csv'garbage file
#'B140818162018.csv', incomplete

model_A8= "ar"
width_A8 = 100
jump_A8 = 10
dim_A8 = 5
sigma_A8 = 1
params_A8 = [0,2]
data_vis = "on"
bkps_vis = "off"#"on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A8/"

for i in range(len(file_list_A8)):
    drifter_id = file_list_A8[i][0:3]
    path_A8 = common_path_A8 + file_list_A8[i]
    A8_data, A8_lp,A8_bkps,A8_lp_mean = cross_section_comp(path_A8,drifter_id,model_A8,width_A8,jump_A8,dim_A8,sigma_A8,params_A8,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(A8_lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")

# %% [markdown]
# # A9

# %%
def process_files_for_mp(file_list,common_path,save_path):
    model= "ar"
    width = 100
    jump = 10
    dim = 5
    sigma = 1
    params = [0,2]
    data_vis = "on"
    bkps_vis = "off"#"on"

    for i in range(len(file_list)):
        drifter_id = file_list[i][0:12]
        path = common_path + file_list[i]
        data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis)

        saved_data = pd.DataFrame(lp_mean)        
        saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
    return lp_mean

# %%
#A9
# %run B_series_functions.ipynb
file_list = [
'\B100818152836.csv',
'\B130818152833.csv',
'\B170818152910.csv',
'\B330818152828.csv',
'\B750818152813.csv',
'\B780818152816.csv',
'\B790818152828.csv',
'\B840818152805.csv',
'\B850818152823.csv',
'\B860818152800.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A9/"


        
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A10

# %%
# %run B_series_functions.ipynb
file_list = [
'\B140818153746.csv',
'\B550818153704.csv',
'\B560818153732.csv',
'\B650818153743.csv',
'\B730818153727.csv',
'\B740818153745.csv',
'\B800818153749.csv',
'\B820818143747.csv',
'\B830818153759.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A10/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A11

# %%
# %run B_series_functions.ipynb
file_list = [
'\B550818155026.csv',
'\B560818155107.csv',
'\B740818155126.csv',
'\B790818155150.csv',
'\B800818155147.csv',
'\B820818145151.csv',
'\B830818155203.csv',
'\B840818155159.csv',
'\B850818155219.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A11/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A12

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818160001.csv',
'\B130818155958.csv',
'\B140818155949.csv',
'\B170818160039.csv',
'\B330818160007.csv',
'\B650818155958.csv',
'\B730818155945.csv',
'\B750818160007.csv',
'\B780818160012.csv',
'\B860818155949.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A12/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A15

# %%
# %run B_series_functions.ipynb
file_list_A15 = ['B330818171826.csv',
'B550818171746.csv',
'B680818171831.csv',
'B740818171835.csv',
'B800818171840.csv',
'B840818171835.csv',
'B850818171902.csv']

# incomplete transect B730818162848.csv'
common_path_A15 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A15_A1/"
model_A15= "ar"
width_A15 = 100
jump_A15 = 10
dim_A15 = 5
sigma_A15 = 1.36
params_A15 = [0,1,2]
data_vis = "off"
bkps_vis = "off"#"on"


for i in range(len(file_list_A15)):
    k = 12*i
    drifter_id = file_list_A15[i][0:3]
    path_A15 = common_path_A15 + file_list_A15[i]
    A15_data, A15_lp,A15_bkps,A15_lp_mean = cross_section_comp(path_A15,drifter_id,model_A15,width_A15,jump_A15,dim_A15,sigma_A15,params_A15,data_vis,bkps_vis,k)
    start = A15_bkps[0]
    print("start",start,drifter_id)
    end = A15_bkps[-1]
    if bkps_vis == "on":
        #show ruptures breakpoints
        rpt.show.display(A15_data[:,params_A15], A15_bkps, figsize=(10, 6))
    if data_vis =="on":
        plt.subplot(len(file_list_A15),1,i+1)
        plt.plot(time_array(start,end),A15_lp_mean[start:end],label = drifter_id)#plot wit seconds on x axis
        #plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x
        plt.ylabel('Pressure []')
        #plt.plot(time_array(start,end),acc_abs[start:end]+k)

save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A15/"

for i in range(len(file_list_A15)):
    drifter_id = file_list_A15[i][0:3]
    path_A15 = common_path_A15 + file_list_A15[i]
    A15_data, A15_lp,A15_bkps,A15_lp_mean = cross_section_comp(path_A15,drifter_id,model_A15,width_A15,jump_A15,dim_A15,sigma_A15,params_A15,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(A15_lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")

# %% [markdown]
# # A16

# %%
# %run B_series_functions.ipynb
file_list = [
'\B130818173609.csv',
'\B170818173648.csv',
'\B330818173613.csv',
'\B550818173533.csv',
'\B560818173635.csv',
'\B740818173622.csv',
'\B800818173629.csv',
'\B840818173633.csv',
'\B850818173653.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A16/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A17

# %%
# %run B_series_functions.ipynb
file_list = [
'\B140818174809.csv',
'\B650818174819.csv',
'\B730818174804.csv',
'\B750818174827.csv',
'\B780818174833.csv',
'\B820818164832.csv',
'\B830818174844.csv',
'\B860818174821.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A17/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A18

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818183717.csv',
'\B140818183733.csv',
'\B330818183818.csv',
'\B730818183818.csv',
'\B740818183906.csv',
'\B750818183941.csv',
'\B780818184018.csv',
'\B170818184221.csv',
'\B820818165611.csv',
'\B830818184200.csv',
'\B860818184147.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A18/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A20

# %%
# %run B_series_functions.ipynb
file_list = [
'\B130818185922.csv',
'\B150818185905.csv',
'\B550818185839.csv',
'\B650818185921.csv',
'\B800818185927.csv',
'\B840818185919.csv',
'\B850818185936.csv',
]
#'\B560818185908.csv',
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A20/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A25

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818134757.csv',
'\B330818134755.csv',
'\B550818134710.csv',
'\B560818134740.csv',
'\B650818134756.csv',
'\B730818134747.csv',
'\B740818134809.csv',
'\B750818134821.csv',
'\B790818134839.csv',
'\B800818134833.csv',
'\B830818134842.csv',
'\B840818134834.csv',
'\B860818134827.csv',
]

#'\B560818185908.csv',
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # Load data from other days 2020

# %%
"""15.08.2020 A25 Deployments"""


# %run B_series_functions.ipynb
file_list = [
"\B080815185830.csv",
"\B680815190017.csv",
"\B170815190312.csv",
"\B840815190427.csv",
"\B100815190650.csv",
"\B830815190811.csv",
"\B330815191035.csv",
"\B080815201322.csv",
"\B100815201315.csv",
"\B170815201430.csv",
"\B330815201357.csv",
"\B680815201348.csv",
"\B830815201405.csv",
"\B840815201357.csv",
"\B080815205152.csv",
"\B100815210659.csv",
"\B170815205235.csv",
"\B680815205133.csv",
"\B830815205120.csv",
"\B840815205106.csv",
"\B080815215122.csv",
"\B100815215110.csv",
"\B170815215144.csv",
"\B830815215113.csv",
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/all_deployments_15082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_15082020/"
process_files_for_mp(file_list,common_path,save_path)

# %%
# %run B_series_functions.ipynb
"""16082020"""
print('1608')
file_list = [
"\B080816211125.csv",
"\B170816211202.csv",
"\B330816211123.csv",
"\B680816211110.csv",
"\B840816211107.csv",
"\B080816221616.csv",
"\B170816221342.csv",
"\B330816221302.csv",
"\B680816221251.csv",
"\B830816221259.csv",
"\B840816221248.csv",]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/all_deployments_16082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_16082020/"
process_files_for_mp(file_list,common_path,save_path)

# %%
"""17072020"""
# %run B_series_functions.ipynb
"""17082020"""
print('1708')
file_list = [
"\B080817185719.csv",
"\B080817194711.csv",
"\B080817203909.csv",
"\B100817185216.csv",
"\B100817194656.csv",
"\B100817203625.csv",
"\B170817185244.csv",
"\B170817194728.csv",
"\B170817203929.csv",
"\B330817185204.csv",
"\B330817194646.csv",
"\B330817203612.csv",
"\B680817185148.csv",
"\B680817194630.csv",
"\B680817203610.csv",
"\B830817185154.csv",
"\B830817194634.csv",
"\B830817203600.csv",
"\B840817204053.csv",
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/all_deployments_17082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_17082020/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 1708
# \B080817185719
# \B080817194711
# \B080817203909
# \B100817185216
# \B100817194656
# \B100817203625
# \B170817185244
# \B170817194728
# \B170817203929
# \B330817185204
# \B330817194646
# \B330817203612
# \B680817185148
# \B680817194630
# \B680817203610
# \B830817185154
# \B830817194634
# \B830817203600
# \B840817204053
# array([964.51251536, 891.54732796, 818.20061423, ..., 772.77556234,
#        836.83156218, 899.90168856])

# %% [markdown]
# # Load 2021 data
# Load bseries data from the 2021 channel

# %%
# %run B_series_functions.ipynb
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial channel/13072021/All_Bseries_2021_1307/"
file_list = [
"B850713180305.csv",
"B100713154414.csv",
"B130713165653.csv",
"B150101000000.csv",
"B150602153853.csv",
"B150602161337.csv",
"B150602161415.csv",
"B550713165700.csv",
"B550713180228.csv",
"B731206160254.csv",
"B731206160416.csv",
"B750713165722.csv",
"B750713180252.csv",
"B800713165727.csv",
"B800713180257.csv",
"B850713165747.csv",
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/All_Bseries_2021_1307/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
process_files_for_mp(file_list,common_path,save_path)

# %%
#Load cave deployment

# %run B_series_functions.ipynb
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Kongsvegen_cave/08062021/"
file_list = [
"\B840608200152.csv"
]

save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # DBA
# https://github.com/fpetitjean/DBA

# %% [markdown]
# # Dynamic time warping

# %%
# %run B_series_functions.ipynb 

def dtw_drifters(s1,s2):
    #d, path = dtw.warping_path(s1, s2, window=20, use_pruning=True )
    #best_path = dtw.best_path(paths)
    #dtwvis.plot_warpingpaths(s1, s2, paths, best_path)

    #path = dtw.warping_path(s1, s2,window = 100)
    path = dtw.warping_path(s1, s2)


    dtwvis.plot_warping(s1, s2, path)
    distance = dtw.distance(s1, s2)
    print("Distance = ",distance)

s1 = A14_all[1][0:-29000:10]#A14_df.iloc[0:-159000:10,1].dropna().to_numpy()
s2 = A14_all[2][0:-23500:10]#A14_df.iloc[0:-116500:10,2].dropna().to_numpy()

s3 = A6_all[1][0:-17350:10]
s4 = A6_all[2][0:-14100:10]


#s3 = A14_df.iloc[0:58300:10,1].dropna().to_numpy()
#4 = A14_df.iloc[0:100800:10,2].dropna().to_numpy()

#plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x


dtw_drifters(s1,s2)
dtw_drifters(s3,s4)
