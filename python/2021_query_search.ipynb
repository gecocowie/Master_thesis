# %%
# %run matrix_profile_Bseries.ipynb
plt.close('all')
# Out:
# Cross section:  A5
# Mean steps:  3.0
# Number of deployments: 9
# Std:  0.82
#
# Cross section:  A6
# Mean steps:  5.125
# Number of deployments: 8
# Std:  2.32
#
# Cross section:  A7
# Mean steps:  8.555555555555555
# Number of deployments: 9
# Std:  1.89
#
# Cross section:  A8
# Mean steps:  10.6
# Number of deployments: 10
# Std:  2.87
#
# Cross section:  A9
# Mean steps:  14.6
# Number of deployments: 10
# Std:  4.0
#
# Cross section:  A10
# Mean steps:  22.555555555555557
# Number of deployments: 9
# Std:  3.69
#
# Cross section:  A11
# Mean steps:  23.666666666666668
# Number of deployments: 6
# Std:  3.35
#
# Cross section:  A12
# Mean steps:  26.11111111111111
# Number of deployments: 9
# Std:  2.13
#
# Cross section:  A13
# Mean steps:  34.142857142857146
# Number of deployments: 7
# Std:  5.72
#
# Cross section:  A14
# Mean steps:  43.42857142857143
# Number of deployments: 7
# Std:  1.5
#
# Cross section:  A15
# Mean steps:  52.5
# Number of deployments: 6
# Std:  3.2
#
# Cross section:  A16
# Mean steps:  65.33333333333333
# Number of deployments: 6
# Std:  9.76
#
# Cross section:  A17
# Mean steps:  71.0
# Number of deployments: 3
# Std:  2.16
#
# Cross section:  A18
# Mean steps:  79.75
# Number of deployments: 8
# Std:  15.8
#
# Cross section:  A20
# Mean steps:  101.83333333333333
# Number of deployments: 6
# Std:  9.58
#
# Difference:  1.0
# 0.25
# Difference:  1.9000000000000004
# 0.27
# Difference:  0.40000000000000036
# 0.04
# Difference:  0.40000000000000036
# 0.04
# Difference:  0.5999999999999996
# 0.04
# Difference:  3.6000000000000014
# 0.19
# Difference:  0.3000000000000007
# 0.01
# Difference:  3.8999999999999986
# 0.13
# Difference:  0.6000000000000014
# 0.02
# Difference:  10.5
# 0.19
# Difference:  13.5
# 0.2
# Difference:  11.700000000000003
# 0.15
# Difference:  18.0
# 0.2
# Difference:  15.200000000000003
# 0.16
# Difference:  7.200000000000003
# 0.07
# Mean Absolute Percentage Error:  0.13
# Mean step miscount:  5.920000000000001
# <img src="data:image/png;base64,..." width="1000">
# Step count:  45
# Step count:  41
# Step count:  46
# Step count:  43
# Step count:  43
# Step count:  43
# Step count:  43
# Step count:  12
# Step count:  9
# Step count:  12
# Step count:  14
# Step count:  13
# Step count:  22
# Step count:  22
# Step count:  13
# Step count:  15
# Step count:  14
# Step count:  12
# Step count:  23
# Step count:  26
# Step count:  17
# Step count:  17
# Step count:  26
# Step count:  26
# Step count:  23
# Step count:  26
# Step count:  19
# Step count:  21
# Step count:  26
# Step count:  27
# Step count:  18
# Step count:  27
# Step count:  23
# Step count:  24
# Step count:  29
# Step count:  30
# Step count:  28
# Step count:  25
# Step count:  25
# Step count:  25
# Step count:  24
# Step count:  25
# Step count:  51
# Step count:  52
# Step count:  51
# Step count:  48
# Step count:  55
# Step count:  58
# Step count:  58
# Step count:  84
# Step count:  59
# Step count:  70
# Step count:  66
# Step count:  55
# Step count:  70
# Step count:  69
# Step count:  74
# Step count:  85
# Step count:  115
# Step count:  77
# Step count:  67
# Step count:  90
# Step count:  65
# Step count:  73
# Step count:  66
# <img src="data:image/png;base64,..." width="1000">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Step count:  105
# Step count:  112
# Step count:  98
# Step count:  85
# Step count:  113
# Step count:  98
# Step count:  54
# A20
# Step count:  108
# A20
# Step count:  108
# Step count:  119
# Step count:  107
# Step count:  107
# Step count:  132
# Step count:  103
# A20 error: 112.66666666666667   109
#
# A18
# Step count:  79
# Step count:  118
# Step count:  108
# Step count:  71
# Step count:  105
# Step count:  102
# Step count:  101
# Step count:  93
# A18 mean: 97.125   95
#
# A17
# Step count:  75
# Step count:  93
# Step count:  68
# A17 mean: 78.66666666666667   89
#
# A16
# Step count:  59
# Step count:  55
# Step count:  63
# Step count:  73
# Step count:  67
# Step count:  73
# A16 error: 65.0   77
#
# A15
# Step count:  58
# Step count:  51
# Step count:  55
# Step count:  61
# Step count:  58
# Step count:  49
# A15 error: 55.333333333333336   66
#
# A14
# Step count:  38
# Step count:  45
# Step count:  56
# Step count:  39
# Step count:  57
# Step count:  38
# Step count:  43
# A14 error: 45.142857142857146   54
#
# A13
# Step count:  34
# Step count:  38
# Step count:  33
# Step count:  34
# Step count:  36
# Step count:  34
# Step count:  38
# A13 error: 35.285714285714285   35
#
# A12
# Step count:  27
# Step count:  30
# Step count:  31
# Step count:  27
# Step count:  27
# Step count:  28
# Step count:  29
# Step count:  29
# Step count:  25
# A12 error: 28.11111111111111   30
#
# A11
# Step count:  22
# Step count:  25
# Step count:  27
# Step count:  27
# Step count:  23
# Step count:  30
# A11 error: 25.666666666666668   24
#
# A10
# Step count:  25
# Step count:  23
# Step count:  25
# Step count:  22
# Step count:  20
# Step count:  23
# Step count:  16
# Step count:  18
# Step count:  24
# A10 error: 21.77777777777778   19
#
# A9
# Step count:  17
# Step count:  15
# Step count:  20
# Step count:  21
# Step count:  18
# Step count:  14
# Step count:  21
# Step count:  17
# Step count:  14
# Step count:  15
# A9 error: 17.2   14
#
# A8
# Step count:  14
# Step count:  15
# Step count:  8
# Step count:  12
# Step count:  11
# Step count:  15
# Step count:  15
# Step count:  14
# Step count:  12
# Step count:  11
# A8 error: 12.7   11
#
# A7
# Step count:  11
# Step count:  11
# Step count:  10
# Step count:  11
# Step count:  5
# Step count:  11
# Step count:  14
# Step count:  9
# Step count:  10
# A7 error: 10.222222222222221   9
#
# A6
# Step count:  6
# Step count:  9
# Step count:  4
# Step count:  6
# Step count:  8
# Step count:  6
# Step count:  9
# Step count:  9
# A6 error: 7.125   7
#
# A5
# Step count:  4
# Step count:  4
# Step count:  6
# Step count:  5
# Step count:  7
# Step count:  3
# Step count:  4
# Step count:  4
# Step count:  6
# A5 error: 4.777777777777778   4
# Difference:  -0.7777777777777777
# 0.19
# Difference:  -0.125
# 0.02
# Difference:  -1.2222222222222214
# 0.14
# Difference:  -1.6999999999999993
# 0.15
# Difference:  -3.1999999999999993
# 0.23
# Difference:  -2.7777777777777786
# 0.15
# Difference:  -1.6666666666666679
# 0.07
# Difference:  1.8888888888888893
# 0.06
# Difference:  -0.2857142857142847
# 0.01
# Difference:  8.857142857142854
# 0.16
# Difference:  10.666666666666664
# 0.16
# Difference:  12.0
# 0.16
# Difference:  10.333333333333329
# 0.12
# Difference:  -2.125
# 0.02
# Difference:  -3.6666666666666714
# 0.03
# Mean Absolute Percentage Error:  0.11
# Mean step miscount:  4.086190476190476
# Threshold too high/low:  26.199206349206335
# Step count:  27
# Step count:  29
# [  154   369   950  1613  1670  1920  1928  2112  2271  2550  2640  2862
#   3016  3067  4144  4284  4338  4415  4520  5796  6612  7119  7147  7444
#   7492  8138  8477  8615  9636  9756 10239 10251 10273 10468 10541 10928
#  11829 12012 12486 12575 12778 12975 13035 13076 13283]
# <img src="data:image/png;base64,..." width="1200">
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Mean of random tests:  20.5
# <img src="data:image/png;base64,..." width="1000">
# Step count:  33
# <img src="data:image/png;base64,..." width="1000">
# Step count:  34
# 56
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
B10 =  pd.read_csv(path + 'B10071315441.csv',names = ['time s/100','pressure'],header=0)
B13 =  pd.read_csv(path + 'B13071316565.csv',names = ['time s/100','pressure'],header=0)
B151 = pd.read_csv(path + 'B15010100000.csv',names = ['time s/100','pressure'],header=0)
B152 = pd.read_csv(path + 'B15060215385.csv',names = ['time s/100','pressure'],header=0)
B153 = pd.read_csv(path + 'B15060216133.csv',names = ['time s/100','pressure'],header=0)
B154 = pd.read_csv(path + 'B15060216141.csv',names = ['time s/100','pressure'],header=0)
B551 = pd.read_csv(path + 'B55071316570.csv',names = ['time s/100','pressure'],header=0)
B552 = pd.read_csv(path + 'B55071318022.csv',names = ['time s/100','pressure'],header=0)
B731 = pd.read_csv(path + 'B73120616025.csv',names = ['time s/100','pressure'],header=0)
B732 = pd.read_csv(path + 'B73120616041.csv',names = ['time s/100','pressure'],header=0)
B751 = pd.read_csv(path + 'B75071316572.csv',names = ['time s/100','pressure'],header=0)
B752 = pd.read_csv(path + 'B75071318025.csv',names = ['time s/100','pressure'],header=0)
B801 = pd.read_csv(path + 'B80071316572.csv',names = ['time s/100','pressure'],header=0)
B802 = pd.read_csv(path + 'B80071318025.csv',names = ['time s/100','pressure'],header=0)
B851 = pd.read_csv(path + 'B85071316574.csv',names = ['time s/100','pressure'],header=0)
B852 = pd.read_csv(path + 'B85071318030.csv',names = ['time s/100','pressure'],header=0)

cave_deployment = pd.read_csv(path + 'cave_deployment.csv',names = ['time s/100','pressure'],header=0)

B13 = B13.iloc[20151:51368] 
B551 = B551.iloc[32339:67151]
B552 = B552.iloc[58279:94575]
B751 = B751.iloc[46662:81916]
B752 = B752.iloc[75136:111230]
B801 = B801.iloc[52363:85765]
B851 = B851.iloc[62380:102190]
B852 = B852.iloc[84367:125306]

cave_deployment = cave_deployment.iloc[18196:70542]

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
B56_start = 11861#query start
B56_stop = 11935#query_stop

#video features
query = A14B56['pressure'].values[B56_start:B56_stop]

mp_B13  = mp_query( B13,B56_start,B56_stop,query = query,threshold = 5,data_viz = "on")
mp_B551 = mp_query(B551,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B552 = mp_query(B552,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B751 = mp_query(B751,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B752 = mp_query(B752,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B801 = mp_query(B801,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B851 = mp_query(B851,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")
mp_B852 = mp_query(B852,B56_start,B56_stop,query = query,threshold = 5,data_viz = "off")

Bseries_hits_2021 = np.array([
127,
115,
107,
124,
122,
110,
140,
135])

print("Mean 2021 Bseries:", np.mean(Bseries_hits_2021))

#cross_section_stats(hit_list,name)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Step count:  127
# Step count:  115
# Step count:  107
# Step count:  124
# Step count:  122
# Step count:  110
# Step count:  140
# Step count:  135
# Mean 2021 Bseries: 122.5

# %%
#cave deployment
mp_iterate_query(cave_deployment['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "on")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_9819/3457315043.py in <module>
#       1 #cave deployment
# ----> 2 mp_query(cave_deployment['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "on")
#       3
#
# TypeError: mp_query() got an unexpected keyword argument 'window'

# %% [markdown]
# # Cumulative step search

# %%
#th_iter = 22.62
#window_iter = 280

th_iter = 12.28
window_iter = 90

#A
print('Bseries Kongsvegen mean')
kongsvegen_cum_mean = 0
kongsvegen_cum_mean += mp_iterate_query(B13['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B551['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B552['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B751['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B752['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B801['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B851['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
kongsvegen_cum_mean += mp_iterate_query(B852['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")

kongsvegen_cum_mean = (kongsvegen_cum_mean)/8
print('Bseries Kongsvegen steps:', kongsvegen_cum_mean,' ',95)


B13
B551
B552
B751
B752
B801
B851
B852
# Out:
# Bseries Kongsvegen mean
# Step count:  117
# Step count:  126
# Step count:  144
# Step count:  138
# Step count:  126
# Step count:  136
# Step count:  137
# Step count:  144
# Bseries Kongsvegen steps: 133.5   95
#         time s/100     pressure
# 84367        84367   998.988301
# 84368        84368   998.989943
# 84369        84369   998.990958
# 84370        84370   998.991364
# 84371        84371   998.991170
# ...            ...          ...
# 125301      125301  1005.520078
# 125302      125302  1005.768033
# 125303      125303  1005.956288
# 125304      125304  1006.082703
# 125305      125305  1006.147519
#
# [40939 rows x 2 columns]
