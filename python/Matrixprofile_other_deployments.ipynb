# %% [markdown]
# # Run query search on other deployments 2020
# The original notebook script became too slow to run so i made another one

# %%
# %run matrix_profile_Bseries.ipynb
# %matplotlib inline
plt.close('all')
# Out:
# 39357
# 40851
# 42956
# 42756
# 2717
# <img src="data:image/png;base64,..." width="1000">
# Step count:  45
# <img src="data:image/png;base64,..." width="1400">
# Step count:  41
# Step count:  46
# Step count:  43
# Step count:  43
# Step count:  43
# Step count:  43
# Step count:  11
# <img src="data:image/png;base64,..." width="1400">
# Step count:  12
# Step count:  9
# Step count:  12
# Step count:  14
# Step count:  13
# Step count:  22
# Step count:  22
# Step count:  13
# Step count:  15
# Step count:  14
# Step count:  12
# Step count:  23
# Step count:  26
# Step count:  17
# Step count:  17
# Step count:  26
# Step count:  26
# Step count:  23
# Step count:  26
# Step count:  19
# Step count:  21
# Step count:  26
# Step count:  27
# Step count:  18
# Step count:  27
# Step count:  23
# Step count:  24
# Step count:  29
# Step count:  30
# Step count:  28
# Step count:  25
# Step count:  25
# Step count:  25
# Step count:  24
# Step count:  25
# Step count:  51
# ...

# %%
B56_start = 11861#query start
B56_stop = 11935#query_stop
#video features
query = A14B56['pressure'].values[B56_start:B56_stop]

print(11861/100)
print(11935/100)

"""A25-A1 15082020"""
A25_1508_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_15082020/"
A25_1508_1 = pd.read_csv(A25_1508_path + '\B8408152051.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_2 = pd.read_csv(A25_1508_path + '\B0808151858.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_3 = pd.read_csv(A25_1508_path + '\B0808152013.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_4 = pd.read_csv(A25_1508_path + '\B0808152051.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_5 = pd.read_csv(A25_1508_path + '\B0808152151.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_6 = pd.read_csv(A25_1508_path + '\B1008151906.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_7 = pd.read_csv(A25_1508_path + '\B1008152013.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_8 = pd.read_csv(A25_1508_path + '\B1008152106.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_9 = pd.read_csv(A25_1508_path + '\B1008152151.csv',names = ["time s/100",'pressure'], header=0)
A25_1508_10 = pd.read_csv(A25_1508_path + '\B1708151903.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_11 = pd.read_csv(A25_1508_path + '\B1708152014.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_12 = pd.read_csv(A25_1508_path + '\B1708152052.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_13 = pd.read_csv(A25_1508_path + '\B1708152151.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_14 = pd.read_csv(A25_1508_path + '\B3308151910.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_15 = pd.read_csv(A25_1508_path + '\B3308152013.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_16 = pd.read_csv(A25_1508_path + '\B6808151900.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_17 = pd.read_csv(A25_1508_path + '\B6808152013.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_18 = pd.read_csv(A25_1508_path + '\B6808152051.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_19 = pd.read_csv(A25_1508_path + '\B8308151908.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_20 = pd.read_csv(A25_1508_path + '\B8308152014.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_21 = pd.read_csv(A25_1508_path + '\B8308152051.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_22 = pd.read_csv(A25_1508_path + '\B8308152151.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_23 = pd.read_csv(A25_1508_path + '\B8408151904.csv',names = ["time s/100",'pressure'],header=0)
A25_1508_24 = pd.read_csv(A25_1508_path + '\B8408152013.csv',names = ["time s/100",'pressure'],header=0)

A25_1508_2 =  A25_1508_2.iloc[10438:61075] 
A25_1508_3 =  A25_1508_3.iloc[11625:64964] 
A25_1508_7 =  A25_1508_7.iloc[16070:76933] 
A25_1508_10 = A25_1508_10.iloc[7630:60250]
A25_1508_11 = A25_1508_11.iloc[17371:77312]
A25_1508_12 = A25_1508_12.iloc[74490:140242]
A25_1508_16 = A25_1508_16.iloc[7048:61060]
A25_1508_17 = A25_1508_17.iloc[27055:80990]
A25_1508_23 = A25_1508_23.iloc[5201:61550]#weird readings

A25_1608_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_16082020/"
A25_1608_1  = pd.read_csv(A25_1608_path + "\B0808162111.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_2  = pd.read_csv(A25_1608_path + "\B1708162112.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_3  = pd.read_csv(A25_1608_path + "\B3308162111.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_4  = pd.read_csv(A25_1608_path + "\B6808162111.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_5  = pd.read_csv(A25_1608_path + "\B8408162111.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_6  = pd.read_csv(A25_1608_path + "\B0808162216.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_7  = pd.read_csv(A25_1608_path + "\B1708162213.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_8  = pd.read_csv(A25_1608_path + "\B3308162213.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_9  = pd.read_csv(A25_1608_path + "\B6808162212.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_10 = pd.read_csv(A25_1608_path + "\B8308162212.csv",names = ["time s/100", "pressure"],header=0)
A25_1608_11 = pd.read_csv(A25_1608_path + "\B8408162212.csv",names = ["time s/100", "pressure"],header=0)

A25_1608_1 = A25_1608_1.iloc[28107:90686] 
A25_1608_2 = A25_1608_2.iloc[31630:91400] 
A25_1608_3 = A25_1608_3.iloc[36822:99600] 
A25_1608_4 = A25_1608_4.iloc[42490:107449] 
A25_1608_5 = A25_1608_5.iloc[55227:118006] 
A25_1608_6 = A25_1608_6.iloc[6258:83949] 
A25_1608_7 = A25_1608_7.iloc[28090:98178] 
A25_1608_8 = A25_1608_8.iloc[33315:105221] 
A25_1608_9 = A25_1608_9.iloc[38497:109467]

A25_1708_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25_17082020/"
A25_1708_1 =  pd.read_csv(A25_1708_path + "\B0808171857.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_2 =  pd.read_csv(A25_1708_path + "\B0808171947.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_3 =  pd.read_csv(A25_1708_path + "\B0808172039.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_4 =  pd.read_csv(A25_1708_path + "\B1008171852.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_5 =  pd.read_csv(A25_1708_path + "\B1008171946.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_6 =  pd.read_csv(A25_1708_path + "\B1008172036.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_7 =  pd.read_csv(A25_1708_path + "\B1708171852.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_8 =  pd.read_csv(A25_1708_path + "\B1708171947.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_9 =  pd.read_csv(A25_1708_path + "\B1708172039.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_10 = pd.read_csv(A25_1708_path + "\B3308171852.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_11 = pd.read_csv(A25_1708_path + "\B3308171946.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_12 = pd.read_csv(A25_1708_path + "\B3308172036.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_13 = pd.read_csv(A25_1708_path + "\B6808171851.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_14 = pd.read_csv(A25_1708_path + "\B6808171946.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_15 = pd.read_csv(A25_1708_path + "\B6808172036.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_16 = pd.read_csv(A25_1708_path + "\B8308171851.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_17 = pd.read_csv(A25_1708_path + "\B8308171946.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_18 = pd.read_csv(A25_1708_path + "\B8308172036.csv",names = ["time s/100","pressure"],header = 0)
A25_1708_19 = pd.read_csv(A25_1708_path + "\B8408172040.csv",names = ["time s/100","pressure"],header = 0)


A25_1708_1  =  A25_1708_1.iloc[6847:63710]
A25_1708_2  =  A25_1708_2.iloc[24486:81318]
A25_1708_3  =  A25_1708_3.iloc[7266:70950]
A25_1708_4  =  A25_1708_4.iloc[40100:101000]
A25_1708_5  =  A25_1708_5.iloc[29848:89850]
A25_1708_8  =  A25_1708_8.iloc[35853:102626]
A25_1708_9  =  A25_1708_9.iloc[17856:82245]
A25_1708_10 = A25_1708_10.iloc[50440:111816]
A25_1708_11 = A25_1708_11.iloc[40939:105431]
A25_1708_13 = A25_1708_13.iloc[56169:113101]
A25_1708_14 = A25_1708_14.iloc[46485:110150]
A25_1708_16 = A25_1708_16.iloc[67300:127670]
A25_1708_17 = A25_1708_17.iloc[54309:123117]
# Out:
# 118.61
# 119.35

# %%
fig, ax = plt.subplots(figsize=(14,10))
t = np.linspace(0,len(query),len(query))/100
ax.plot(t,query,linewidth = "3",c = "#648FFF",label = "Query subsequence")
ax.set_xlabel("Duration [s]")
ax.set_ylabel("Pressure [hPa]")
ax.legend()
print(len(query))
# Out:
# 74

# %%
"""x = A25_1708_1["pressure"].iloc[6847:63710]
x = A25_1708_2["pressure"].iloc[24486:81318]
x = A25_1708_3["pressure"].iloc[7266:70950]
x = A25_1708_4["pressure"].iloc[40100:101000]
x = A25_1708_5["pressure"].iloc[29848:89850]
x = A25_1708_8["pressure"].iloc[35853:102626]
x = A25_1708_9["pressure"].iloc[17856:82245]
x = A25_1708_10["pressure"].iloc[50440:111816]
x = A25_1708_11["pressure"].iloc[40939:105431]
x = A25_1708_13["pressure"].iloc[56169:113101]
x = A25_1708_14["pressure"].iloc[46485:110150]
x = A25_1708_16["pressure"].iloc[67300:127670]
x = A25_1708_17["pressure"].iloc[54309:123117]"""

x = A25_1708_2["pressure"]
fig, ax = plt.subplots()
ax.plot(x)

# %%
"""print(len(A25_1508_2)) 
print(len(A25_1508_3)) 
print(len(A25_1508_7)) 
print(len(A25_1508_10))
print(len(A25_1508_11))
print(len(A25_1508_12))
print(len(A25_1508_16))
print(len(A25_1508_17))
print(len(A25_1508_23))"""

      
"""print(len(A25_1608_1))
print(len(A25_1608_2))
print(len(A25_1608_3))
print(len(A25_1608_4))
print(len(A25_1608_5))
print(len(A25_1608_6))
print(len(A25_1608_7))
print(len(A25_1608_8))
print(len(A25_1608_9))"""


print(len(A25_1708_1 ))
print(len(A25_1708_2 ))
print(len(A25_1708_3 ))
print(len(A25_1708_4 ))
print(len(A25_1708_5 ))
print(len(A25_1708_8 ))
print(len(A25_1708_9 ))
print(len(A25_1708_10))
print(len(A25_1708_11))
print(len(A25_1708_13))
print(len(A25_1708_14))
print(len(A25_1708_16))
print(len(A25_1708_17))
# Out:
# 56863
# 56832
# 63684
# 60900
# 60002
# 66773
# 64389
# 61376
# 64492
# 56932
# 63665
# 60370
# 68808

# %%
import time

t0 = time.time()

dp_15_1 = mp_query(A25_1508_2,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_2 = mp_query(A25_1508_3,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_3 = mp_query(A25_1508_7,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_4 = mp_query(A25_1508_10,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_5 = mp_query(A25_1508_11,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_6 = mp_query(A25_1508_12,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_7 = mp_query(A25_1508_16,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_8 = mp_query(A25_1508_17,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_15_9 = mp_query(A25_1508_23,B56_start,B56_stop,query,threshold = 5,data_viz='off')
single_query_mean_15 = (166+144+170+145+165+178+174+163+164)/9
print('Mean step count single query: ', single_query_mean_15)
t1 = time.time()

total = t1-t0
print("Total time single ",total)

t02 = time.time()
th_iter = 12.28
window_iter = 90
print('A25 1508 iterative query')
A25_1508_mean = 0
A25_1508_mean,dp_15_1_i = mp_iterate_query( A25_1508_2['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
A25_1508_mean,dp_15_2_i = mp_iterate_query( A25_1508_3['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
A25_1508_mean,dp_15_3_i = mp_iterate_query( A25_1508_7['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
A25_1508_mean,dp_15_4_i = mp_iterate_query( A25_1508_10['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean,dp_15_5_i = mp_iterate_query( A25_1508_11['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean,dp_15_6_i = mp_iterate_query( A25_1508_12['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean,dp_15_7_i = mp_iterate_query( A25_1508_16['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean,dp_15_8_i = mp_iterate_query( A25_1508_17['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean,dp_15_9_i = mp_iterate_query( A25_1508_23['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
A25_1508_mean = A25_1508_mean/9
print('A25 1508 error:', A25_1508_mean,' ',155)

t12 = time.time()
total = t12-t02
print("Total time iterative ",total)
# Out:
# Step count:  166
# Step count:  144
# Step count:  170
# Step count:  145
# Step count:  165
# Step count:  178
# Step count:  174
# Step count:  163
# Step count:  164
# Mean step count single query:  163.22222222222223
# Total time single  0.7682738304138184
# A25 1508 iterative query
# Step count:  169
# Step count:  166
# Step count:  179
# Step count:  180
# Step count:  191
# Step count:  204
# Step count:  186
# Step count:  196
# Step count:  192
# A25 1508 error: 21.333333333333332   155
# Total time iterative  8.956258058547974

# %%
t0 = time.time()

dp_16_1 = mp_query(A25_1608_1,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_2 = mp_query(A25_1608_2,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_3 = mp_query(A25_1608_3,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_4 = mp_query(A25_1608_4,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_5 = mp_query(A25_1608_5,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_6 = mp_query(A25_1608_6,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_7 = mp_query(A25_1608_7,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_8 = mp_query(A25_1608_8,B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_16_9 = mp_query(A25_1608_9,B56_start,B56_stop,query,threshold = 5,data_viz='off')
single_query_mean_16 = (175+ 179+ 166+ 175+ 188+ 213+ 174+ 204+ 192)/9
print('Mean step count single query: ', single_query_mean_16)



print('\nA25 1608 iterative')
A25_1608_mean = 0
A25_1608_mean += mp_iterate_query(A25_1608_1['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_2['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_3['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_4['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_5['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_6['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_7['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_8['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean += mp_iterate_query(A25_1608_9['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
A25_1608_mean = A25_1608_mean/9
print('A25 1608 error:', A25_1608_mean,' ',155)
# Out:
# Step count:  175
# Step count:  179
# Step count:  166
# Step count:  175
# Step count:  188
# Step count:  213
# Step count:  174
# Step count:  204
# Step count:  192
# Mean step count single query:  185.11111111111111
#
# A25 1608 iterative
# Step count:  210
# Step count:  204
# Step count:  220
# Step count:  236
# Step count:  209
# Step count:  264
# Step count:  254
# Step count:  227
# Step count:  241
# A25 1608 error: 229.44444444444446   155

# %%
dp_17_1 = mp_query( A25_1708_1 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_2 = mp_query( A25_1708_2 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_3 = mp_query( A25_1708_3 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_4 = mp_query( A25_1708_4 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_5 = mp_query( A25_1708_5 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_6 = mp_query( A25_1708_8 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_7 = mp_query( A25_1708_9 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_8 = mp_query(A25_1708_10, B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_9 = mp_query(A25_1708_11, B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_10 = mp_query(A25_1708_13, B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_11 = mp_query(A25_1708_14, B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_12 = mp_query(A25_1708_16, B56_start,B56_stop,query,threshold = 5,data_viz='off')
dp_17_13 = mp_query(A25_1708_17, B56_start,B56_stop,query,threshold = 5,data_viz='off')

single_query_mean_17 = (173+183+187+174+168+153+180+163+173+165+183+179+195)/13
print('Mean step count single query: ', single_query_mean_17)

print('\nA25 1608 iterative')
A25_1708_mean = 0
A25_1708_mean,mp_17_i_1 = mp_iterate_query( A25_1708_1["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_2 = mp_iterate_query( A25_1708_2["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_3 = mp_iterate_query( A25_1708_3["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_4 = mp_iterate_query( A25_1708_4["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_5 = mp_iterate_query( A25_1708_5["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_6 = mp_iterate_query( A25_1708_8["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_7 = mp_iterate_query( A25_1708_9["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_8 = mp_iterate_query(A25_1708_10["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_9 = mp_iterate_query(A25_1708_11["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_10 = mp_iterate_query(A25_1708_13["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_11 = mp_iterate_query(A25_1708_14["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_12 = mp_iterate_query(A25_1708_16["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
A25_1708_mean,mp_17_i_13 = mp_iterate_query(A25_1708_17["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")

A25_1708_mean = A25_1708_mean/13
print('A25 1708 error:', A25_1708_mean,' ',155)
# Out:
# Step count:  173
# Step count:  183
# Step count:  187
# Step count:  174
# Step count:  168
# Step count:  153
# Step count:  180
# Step count:  163
# Step count:  173
# Step count:  165
# Step count:  183
# Step count:  179
# Step count:  195
# Mean step count single query:  175.07692307692307
#
# A25 1608 iterative
# Step count:  183
# Step count:  187
# Step count:  207
# Step count:  190
# Step count:  214
# Step count:  232
# Step count:  223
# Step count:  216
# Step count:  223
# Step count:  195
# Step count:  218
# Step count:  203
# Step count:  232
# A25 1708 error: 17.846153846153847   155

# %% [markdown]
# # Time processing time

# %%
import time
th_iter = 12.28
window_iter = 90
t0 = time.time()

mp_query(A25_1508_2,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_3,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_7,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_10,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_11,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_12,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_16,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_17,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1508_23,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_1,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_2,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_3,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_4,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_5,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_6,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_7,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_8,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1608_9,B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_1 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_2 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_3 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_4 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_5 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_8 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query( A25_1708_9 , B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_10, B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_11, B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_13, B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_14, B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_16, B56_start,B56_stop,query,threshold = 5,data_viz='off')
mp_query(A25_1708_17, B56_start,B56_stop,query,threshold = 5,data_viz='off')

t1 = time.time()
total = t1-t0
print("Total time single ",total)

t02 = time.time()

mp_iterate_query( A25_1508_2['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
mp_iterate_query( A25_1508_3['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
mp_iterate_query( A25_1508_7['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off" ,return_mp = "on")
mp_iterate_query( A25_1508_10['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query( A25_1508_11['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query( A25_1508_12['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query( A25_1508_16['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query( A25_1508_17['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query( A25_1508_23['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp = "on")
mp_iterate_query(A25_1608_1['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_2['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_3['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_4['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_5['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_6['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_7['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_8['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query(A25_1608_9['pressure'].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off")
mp_iterate_query( A25_1708_1["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_2["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_3["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_4["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_5["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_8["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query( A25_1708_9["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_10["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_11["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_13["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_14["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_16["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")
mp_iterate_query(A25_1708_17["pressure"].values,A14B56['pressure'].values,window = window_iter,threshold = th_iter,features = steps_idx,data_viz = "off",return_mp="on")

t12 = time.time()
total = t12-t02
print("Total time iterative ",total)

#33.15233898162842
#3.0358190536499023
#31.758744955062866
#2.8345518112182617
#31.725997924804688
#2.8277459144592285

z = (31.725997924804688+31.758744955062866+33.15233898162842)/3
p = (3.0358190536499023+2.8345518112182617+2.8277459144592285)/3
print(z)
print(p)
# Out:
# Step count:  166
# Step count:  144
# Step count:  170
# Step count:  145
# Step count:  165
# Step count:  178
# Step count:  174
# Step count:  163
# Step count:  164
# Step count:  175
# Step count:  179
# Step count:  166
# Step count:  175
# Step count:  188
# Step count:  213
# Step count:  174
# Step count:  204
# Step count:  192
# Step count:  173
# Step count:  183
# Step count:  187
# Step count:  174
# Step count:  168
# Step count:  153
# Step count:  180
# Step count:  163
# Step count:  173
# Step count:  165
# Step count:  183
# Step count:  179
# Step count:  195
# Total time single  2.848829984664917
# Step count:  169
# Step count:  166
# Step count:  179
# Step count:  180
# Step count:  191
# Step count:  204
# Step count:  186
# Step count:  196
# Step count:  192
# Step count:  210
# Step count:  204
# Step count:  220
# Step count:  236
# Step count:  209
# Step count:  264
# Step count:  254
# Step count:  227
# Step count:  241
# Step count:  183
# ...

# %%
fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_15_1+1,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_2+3,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_3+8,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_4+2,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_5+7,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_6+9,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_7+5,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_8+4,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_9+6,ls="None",marker = "|",markersize = 50,c = "black")
ax.set_ylim(0,10)
ax.set_title("Single query")
plt.show()

fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_16_1+1,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_2+2,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_3+3,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_4+4,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_5+5,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_6+6,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_7+7,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_8+8,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_16_9+9,ls="None",marker = "|",markersize = 50,c = "black")
ax.set_ylim(0,10)

fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_17_1+1,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_2+2,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_3+3,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_4+4,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_5+5,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_6+6,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_7+7,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_8+8,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_17_9+9,ls="None",marker = "|",markersize = 50,c = "black")
ax.set_ylim(0,10)



save_path_16 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/distance_profiles/16082020"

np.savetxt(save_path_16+"/Single_query_1608"+ "_1",dp_16_1)
np.savetxt(save_path_16+"/Single_query_1608"+ "_2",dp_16_2)
np.savetxt(save_path_16+"/Single_query_1608"+ "_3",dp_16_3)
np.savetxt(save_path_16+"/Single_query_1608"+ "_4",dp_16_4)
np.savetxt(save_path_16+"/Single_query_1608"+ "_5",dp_16_5)
np.savetxt(save_path_16+"/Single_query_1608"+ "_6",dp_16_6)
np.savetxt(save_path_16+"/Single_query_1608"+ "_7",dp_16_7)
np.savetxt(save_path_16+"/Single_query_1608"+ "_8",dp_16_8)
np.savetxt(save_path_16+"/Single_query_1608"+ "_9",dp_16_9)

# %%
"""fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_15_1+1,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_2+3,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_3+8,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_4+2,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_5+7,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_6+9,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_7+5,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_8+4,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_9+6,ls="None",marker = "|",markersize = 50,c = "black")
ax.set_ylim(0,10)
ax.set_title("Single query")
plt.show()"""

def make_equal_length(short,long = dp_15_6):
    n_long = len(long)
    n_short = len(short)
    diff = n_long-n_short
    jump = int(len(short)/diff)
    print(jump)
    k = 0
    for i in range(diff):
        #if short[k] == 0:
            
        short = np.insert(short, k, 100, axis=None)
        k+= jump
    return short
        
        
dp_15_1_ext = make_equal_length(dp_15_1)
dp_15_2_ext = make_equal_length(dp_15_2)
dp_15_3_ext = make_equal_length(dp_15_3)
dp_15_4_ext = make_equal_length(dp_15_4)
dp_15_5_ext = make_equal_length(dp_15_5)
dp_15_7_ext = make_equal_length(dp_15_7)
dp_15_8_ext = make_equal_length(dp_15_8)
dp_15_9_ext = make_equal_length(dp_15_9)

fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_15_6+9,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_1_ext+1,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_2_ext+2,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_3_ext+3,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_4_ext+4,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_5_ext+5,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_7_ext+6,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_8_ext+7,ls="None",marker = "|",markersize = 50,c = "black")
ax.plot(dp_15_9_ext+8,ls="None",marker = "|",markersize = 50,c = "black")
ax.set_ylim(0,10)
ax.set_title("Single query")
plt.show()
# Out:
# 3
# 4
# 12
# 4
# 10
# 4
# 4
# 5

# %%
def steps_per_sec(dp, window = 800):
    #dp distance profile
    #window seconds
    x = np.copy(dp)

    for i in range(len(dp)):
        if dp[i] != 0:
            x[i] = 0     
        else :
            x[i] = 1
    k=0
    steps_p_s = np.zeros(int(len(dp)/window))
    for l in range(0,len(dp),window):

        for i in range(l,l+window):
            if i >= len(x):
                break
            if x[i] == 1:
                j = i+1
                if j >= len(x):
                    break
                while x[j] == 1:
                    x[j] = 0
                    j += 1
                    if j >= len(x):
                        break
                if k >= len(steps_p_s):
                    break  
                steps_p_s[k]+=1
        if k >= len(steps_p_s):
            break
        steps_p_s[k]=steps_p_s[k]/window*100
        k+=1
            
    

    

        
        #steps_p_s[k] =  np.sum(x[i:i+window])
        #print(dp[i:i+10])
        #print(steps_p_s[k])
    print(np.sum(steps_p_s))
    return steps_p_s

sps_1 = steps_per_sec(dp_15_1)
sps_2 = steps_per_sec(dp_15_2)
sps_3 = steps_per_sec(dp_15_3)
sps_4 = steps_per_sec(dp_15_4)
sps_5 = steps_per_sec(dp_15_5)
sps_6 = steps_per_sec(dp_15_6)
sps_7 = steps_per_sec(dp_15_7)
sps_8 = steps_per_sec(dp_15_8)
sps_9 = steps_per_sec(dp_15_9)

fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows= 5,figsize = (14,10))
ax1.plot(sps_1)
ax2.plot(sps_2)
#ax8.plot(sps_3)
ax3.plot(sps_4)
#ax7.plot(sps_5)
#ax6.plot(sps_6)
ax4.plot(sps_7)
ax5.plot(sps_8)
#ax9.plot(sps_9)

x_lim = 55
y_lim = 0.7

#ax1.set_xlim(0,x_lim)
#ax2.set_xlim(0,x_lim)
#ax3.set_xlim(0,x_lim)
#ax4.set_xlim(0,x_lim)
#ax5.set_xlim(0,x_lim)
#ax6.set_xlim(0,45)
#ax7.set_xlim(0,45)
#ax8.set_xlim(0,45)
#ax9.set_xlim(0,45)
plt.show()


fig,(ax1,ax2,ax3) = plt.subplots(nrows= 3,figsize = (14,10))
ax1.plot(sps_1)
ax2.plot(sps_2)
ax3.plot(sps_4)


ax1.set_xlim(0,x_lim)
ax2.set_xlim(0,x_lim)
ax3.set_xlim(0,x_lim)
ax1.set_ylim(0,y_lim)
ax2.set_ylim(0,y_lim)
ax3.set_ylim(0,y_lim)
plt.show()
# Out:
# 20.75
# 18.0
# 21.125
# 18.0
# 20.5
# 22.25
# 21.625
# 20.375
# 20.375

# %%
sps_1 = steps_per_sec(dp_17_1)
sps_2 = steps_per_sec(dp_17_2)
sps_3 = steps_per_sec(dp_17_3)
sps_4 = steps_per_sec(dp_17_4)
sps_5 = steps_per_sec(dp_17_5)
sps_6 = steps_per_sec(dp_17_6)
sps_7 = steps_per_sec(dp_17_7)
sps_8 = steps_per_sec(dp_17_8)
sps_9 = steps_per_sec(dp_17_9)

fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(nrows= 9,figsize = (14,10))
ax1.plot(sps_1)
ax2.plot(sps_2)
ax8.plot(sps_3)
ax3.plot(sps_4)
ax7.plot(sps_5)
ax6.plot(sps_6)
ax4.plot(sps_7)
ax5.plot(sps_8)
ax9.plot(sps_9)

x_lim = 56
y_lim = 0.8

#ax1.set_xlim(0,x_lim)
#ax2.set_xlim(0,x_lim)
#ax3.set_xlim(0,x_lim)
#ax4.set_xlim(0,x_lim)
#ax5.set_xlim(0,x_lim)
#ax6.set_xlim(0,45)
#ax7.set_xlim(0,45)
#ax8.set_xlim(0,45)
#ax9.set_xlim(0,45)
plt.show()


fig,(ax1,ax2) = plt.subplots(nrows= 2,figsize = (14,6))
ax1.plot(sps_1)
ax2.plot(sps_2)

ax1.set_xlim(0,x_lim)
ax2.set_xlim(0,x_lim)
ax1.set_ylim(0,y_lim)
ax2.set_ylim(0,y_lim)

plt.show()
# Out:
# 21.25
# 22.625
# 23.375
# 21.75
# 20.875
# 19.125
# 22.5
# 20.375
# 21.625

# %%
sps_1_i = steps_per_sec(mp_17_i_1)
sps_2_i = steps_per_sec(mp_17_i_2)
sps_3_i = steps_per_sec(mp_17_i_3)
sps_4_i = steps_per_sec(mp_17_i_4)
sps_6_i = steps_per_sec(mp_17_i_5)
sps_5_i = steps_per_sec(mp_17_i_6)
sps_7_i = steps_per_sec(mp_17_i_7)
sps_8_i = steps_per_sec(mp_17_i_8)
sps_9_i = steps_per_sec(mp_17_i_9)

fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(nrows= 9,figsize = (14,10))
ax1.plot(sps_1_i)
ax2.plot(sps_2_i)
ax8.plot(sps_3_i)
ax3.plot(sps_4_i)
ax4.plot(sps_5_i)
ax6.plot(sps_6_i)
ax7.plot(sps_7_i)
ax5.plot(sps_8_i)
ax9.plot(sps_9_i)

x_lim = 100
y_lim = 1

ax1.set_xlim(0,x_lim)
ax2.set_xlim(0,x_lim)
ax3.set_xlim(0,x_lim)
ax4.set_xlim(0,x_lim)
ax5.set_xlim(0,x_lim)
ax6.set_xlim(0,x_lim)
ax7.set_xlim(0,x_lim)
ax8.set_xlim(0,x_lim)
ax9.set_xlim(0,x_lim)
plt.show()


fig,(ax1,ax2,ax3,ax4) = plt.subplots(nrows= 4,figsize = (14,6))
ax1.plot(sps_1,c="r")
ax2.plot(sps_2,c="r")
ax3.plot(sps_1_i,c="blue")
ax4.plot(sps_2_i,c="blue")



ax1.set_xlim(0,x_lim)
ax2.set_xlim(0,x_lim)
ax1.set_ylim(0,y_lim)
ax2.set_ylim(0,y_lim)
ax3.set_xlim(0,x_lim)
ax4.set_xlim(0,x_lim)
ax3.set_ylim(0,y_lim)
ax4.set_ylim(0,y_lim)

plt.show()
# Out:
# 22.625
# 23.125
# 25.75
# 23.75
# 26.375
# 29.0
# 27.75
# 26.625
# 27.625

# %%
"""iterative query"""
sps_1 = steps_per_sec(dp_15_1_i)
sps_2 = steps_per_sec(dp_15_2_i)
sps_3 = steps_per_sec(dp_15_3_i)
sps_4 = steps_per_sec(dp_15_4_i)
sps_5 = steps_per_sec(dp_15_5_i)
sps_6 = steps_per_sec(dp_15_6_i)
sps_7 = steps_per_sec(dp_15_7_i)
sps_8 = steps_per_sec(dp_15_8_i)
sps_9 = steps_per_sec(dp_15_9_i)

fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(nrows= 9,figsize = (14,10))
ax3.plot(sps_1)
ax4.plot(sps_2)
ax1.plot(sps_3)
ax2.plot(sps_4)
ax5.plot(sps_5)
ax6.plot(sps_6)
ax7.plot(sps_7)
ax8.plot(sps_8)
ax9.plot(sps_9)
ax1.set_xlim(0,45)
ax2.set_xlim(0,45)
ax3.set_xlim(0,45)
ax4.set_xlim(0,45)
ax5.set_xlim(0,45)
ax6.set_xlim(0,45)
ax7.set_xlim(0,45)
ax8.set_xlim(0,45)
ax9.set_xlim(0,45)
plt.show()

fig,ax = plt.subplots(figsize = (14,10))
ax.plot(dp_15_1+1,ls="None",marker = "|",markersize = 50,c = "black")

ax.set_ylim(0,10)
ax.set_title("Single query")
plt.show()
# Out:
# 21.125
# 20.75
# 22.25
# 22.25
# 23.625
# 25.5
# 23.125
# 24.5
# 24.0
