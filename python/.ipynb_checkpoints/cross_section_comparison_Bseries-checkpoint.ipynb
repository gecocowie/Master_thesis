# %% [markdown]
# # B series cross section comparison
#
# Compare runs of the Bseries tubes from the 18-08.2020. Multiple drifters are deployed from each cross section.
#
# procedure:
#
# 1. Find beginning of deployment by running cpd on pressure data (pressure is more reliable than acc because the pressure doese not increase before hitting the water)
# 2. Cut datasets to the first cp detected
#
# ## Potential sections that were filmed at least once:
# A5-A1 8 videos
#
# A6-A1 5
#
# A7-1 1
#
# A8-A1 2 Only one analysed til now
#
# A13-A1 1
#
# A14-A1 1
#
# A15-A1 1

# %% [markdown]
# # Load channel features

# %% [markdown]
# # Cross sections A5-A1

# %%
# %run B_series_functions.ipynb
common_path_A5 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A5_A1/"
B10_A5_path = common_path_A5+'B100818144137.csv'
B14_A5_path = common_path_A5+'B140818144102.csv'
B17_A5_path = common_path_A5+'B170818144158.csv'
B56_A5_path = common_path_A5+'B560818144115.csv'
B75_A5_path = common_path_A5+'B750818144132.csv'
B79_A5_path = common_path_A5+'B790818144150.csv'
B80_A5_path = common_path_A5+'B800818144146.csv'
B82_A5_path = common_path_A5+'B820818134146.csv'
B85_A5_path = common_path_A5+'B850818144158.csv'
B86_A5_path = common_path_A5+'B860818144137.csv'
#cross_section_comp(B10_A5_path,"B10 A5")
#cross_section_comp(filepath,name,model,width,jump,dim,sigma):
model_A5= "ar"
width_A5 = 100
jump_A5 = 10
dim_A5 = 5
sigma_A5 = 0.7
params_A5 = [0,2]
data_vis = "on"
bkps_vis = "off"#"on"
#A5_data, A5_lp,A5_bkps = cross_section_comp(B14_A5_path,"B14 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=0)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B17_A5_path,"B17 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=10)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B56_A5_path,"B56 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=15)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B75_A5_path,"B75 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=20)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B79_A5_path,"B79 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=30)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B80_A5_path,"B80 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=40)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B82_A5_path,"B82 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=50)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B85_A5_path,"B85 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=60)
#A5_data, A5_lp,A5_bkps = cross_section_comp(B86_A5_path,"B86 A5",model_A5,width_A5,jump_A5,dim_A5,sigma_A5,params_A5,data_vis,bkps_vis,k=70)

# %% [markdown]
# # A13 - A1

# %%
# %run B_series_functions.ipynb
file_list_A13 = ['B140818162018.csv','B330818161829.csv','B550818161744.csv','B650818161823.csv','B740818161829.csv','B750818161826.csv','B790818161851.csv','B800818161843.csv','B860818161826.csv']
#'B830818161850.csv'garbage file
#'B140818162018.csv', incomplete

common_path_A13 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A13_A1/"
model_A13= "ar"
width_A13 = 100
jump_A13 = 10
dim_A13 = 5
sigma_A13 = 1
params_A13 = [0,2]
data_vis = "off"
bkps_vis = "off"#"on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A13/"

for i in range(len(file_list_A13)):
    drifter_id = file_list_A13[i][0:3]
    path_A13 = common_path_A13 + file_list_A13[i]
    A13_data, A13_lp,A13_bkps,A13_lp_mean = cross_section_comp(path_A13,drifter_id,model_A13,width_A13,jump_A13,dim_A13,sigma_A13,params_A13,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(A13_lp_mean)        
    #saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A13_A1/B140818162018
# B14 - Number of detected cp:  74
# /A13_A1/B330818161829
# B33 - Number of detected cp:  17
# /A13_A1/B550818161744
# B55 - Number of detected cp:  52
# /A13_A1/B650818161823
# B65 - Number of detected cp:  43
# /A13_A1/B740818161829
# B74 - Number of detected cp:  54
# /A13_A1/B750818161826
# B75 - Number of detected cp:  43
# /A13_A1/B790818161851
# B79 - Number of detected cp:  34
# /A13_A1/B800818161843
# B80 - Number of detected cp:  40
# /A13_A1/B860818161826
# B86 - Number of detected cp:  59

# %% [markdown]
# # Cross section A14 - A1

# %%
# %run B_series_functions.ipynb 
"""B56 A14 A1"""
A14_start = 12990#12729#B56_bkps[0]#12729
A14_end = 27149
time_A14 = time_array(A14_start,A14_end)
A14_vcp = np.array([0.0,1.6,2.5,3.3,6.0,7.5,8.2,10.2,13.3,14.1,15.1,21.1,22.4,23.4,24.2,26.1,28.8,33.4,35.0,36.0,36.1,38.3,42.4,46.1,47.4,49.1,58.4,59.2,59.9,63.8,65.5,73.5,77.4,82.1,87.1,89.0,91.6,93.2,98.6,105.5,111.5,116.4,117.5,120.2,121.8,133.1,134.6,135.7,140.0])
A14_vcp_idx = index_finder(A14_vcp,time_A14,A14_start)-A14_start
A14_meanders = np.array([1.0,9.4,11.7,14.5,33.1,34.0,37.7,38.4,41.5,42.4,46.0,47.7,48.9,57.7,62.7,64.5,65.8,66.9,72.9,74.9,80.4,87.7,90.3,92.0,93.7,104.5,110.6,112.0,117.9,124.2,137.0])
A14_meanders_idx = index_finder(A14_meanders,time_A14,A14_start)-A14_start
"""Load B56 A14 start stop"""
B56_A14_excel_sheet_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/drifter_videos/2020/Drifter_videofeatures_start_stop_2020.xlsx"
B56_A14_SS = pd.read_excel(B56_A14_excel_sheet_path,header = 8)
B56_A14_HF_start = B56_A14_SS["Start_corr"]
B56_A14_HF_stop = B56_A14_SS["Stop_corr"]

# %%
# %run B_series_functions.ipynb

file_list_A14 = ['B130818162912.csv','B170818162956.csv','B560818162851.csv','B780818162912.csv','B820818152908.csv','B840818162908.csv','B850818162932.csv']
#garbage file 'B680818162902.csv'
# incomplete transect B730818162848.csv'
common_path_A14 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A14_A1/"
model_A14= "ar"
width_A14 = 100
jump_A14 = 10
dim_A14 = 5
sigma_A14 = 1.5
params_A14 = [0,1,2,3,4]
data_vis = "on"
bkps_vis = "off"#"on"
save_file = "on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A14/"

# define subplot grid
plt.subplots(nrows=len(file_list_A14), ncols=1, figsize=(10, 12))


plt.rcParams['font.size'] = '12'
#A14_df = pd.DataFrame()
A14_all = []
for i in range(len(file_list_A14)):
    drifter_id = file_list_A14[i][0:3]
    path_A14 = common_path_A14 + file_list_A14[i]
    A14_data, A14_lp,A14_bkps,A14_lp_mean = cross_section_comp(path_A14,drifter_id,model_A14,width_A14,jump_A14,dim_A14,sigma_A14,params_A14,data_vis,bkps_vis)
    
    if drifter_id == "B56":
        #align observed cp with data
        start = A14_bkps[0]-400
        print("B56 start",start,drifter_id)
        end = A14_bkps[-1]
    else:
        start = A14_bkps[0]
        print("start",start,drifter_id)
        end = A14_bkps[-1]
    
    new_A14 = pd.DataFrame(A14_lp_mean[start:end],columns=[drifter_id])
    #A14_df = pd.concat([A14_df,new_A14])
    A14_all.append(A14_lp_mean[start:end])

    if bkps_vis == "on":
        #show ruptures breakpoints
        rpt.show.display(A14_data[:,params_A14], A14_bkps, figsize=(6, 6))
    if data_vis =="on":
        ax = plt.subplot(len(file_list_A14),1,i+1)
        ax.plot(time_array(start,end),A14_lp_mean[start:end],label = drifter_id)#plot wit seconds on x axis
        ax.set_xlim(left=0, right=150)
        #plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x
        ax.set_ylabel('Pressure [dbar]')
        #plt.plot(time_array(start,end),acc_abs[start:end]+k)
        
            
        if(drifter_id == "B56"):
            time_A14 = time_array(start,end)

            A14_HF_start_idx = index_finder(B56_A14_SS["Start_corr"],time_A14,start)-start
            A14_HF_stop_idx = index_finder(B56_A14_HF_stop,time_A14,start)-start


            plt.plot(time_array(start,end)[A14_vcp_idx],np.ones(len(A14_vcp_idx))*A14_lp_mean[A14_vcp_idx+start],marker = "^", color = "y", label = "Hydrologic features",ls = "None")
            #plt.plot(time_array(start,end)[A14_meanders_idx],np.ones(len(A14_meanders_idx))*A14_lp_mean[A14_meanders_idx+start],marker = "*", color = "b", label = "Meanders",ls = "None")
            
            plt.plot(time_A14[A14_HF_start_idx],np.ones(len(A14_HF_start_idx))*A14_lp_mean[A14_HF_start_idx+start],marker = '|',color = 'r',ls = "None",markersize = 30)
            plt.plot(time_A14[A14_HF_stop_idx],np.ones(len(A14_HF_stop_idx))*A14_lp_mean[A14_HF_stop_idx+start],marker = '|',color = 'g',ls = "None",markersize = 25)
        
        if save_file == "on":
            saved_data = pd.DataFrame(A14_lp_mean)
            #saved_data = pd.DataFrame((A14_data[:,0]+A14_data[:,2])/2)
            
            saved_data.to_csv(save_path+drifter_id+".csv")



ax.set_xlabel('Deployment time [s]')
plt.savefig("test")
plt.show()
A14_all = np.array(A14_all,dtype=object)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /A14_A1/B130818162912
# B13 - Number of detected cp:  70
# start 6090 B13
# [[ 1.0001e+03  9.9921e+02  1.0001e+03 -3.6163e-01 -8.7878e-01  2.2217e-02]
#  [ 1.0001e+03  9.9981e+02  1.0001e+03 -3.6163e-01 -8.7878e-01  2.2217e-02]
#  [ 1.0001e+03  9.9891e+02  1.0001e+03 -3.6163e-01 -8.7878e-01  2.2217e-02]
#  ...
#  [ 1.0023e+03  9.8691e+02  1.0035e+03  4.6814e-02 -5.3015e-01 -5.4333e-01]
#  [ 1.0022e+03  9.8671e+02  1.0034e+03  4.2297e-02 -5.1959e-01 -5.6256e-01]
#  [ 1.0022e+03  9.8671e+02  1.0033e+03  4.1626e-02 -5.1202e-01 -5.7629e-01]]
# /A14_A1/B170818162956
# B17 - Number of detected cp:  48
# start 10750 B17
# [[ 9.9987e+02  9.9947e+02  9.9998e+02 -7.9980e-01  5.8099e-01 -2.4414e-03]
#  [ 9.9989e+02  9.9877e+02  9.9996e+02 -7.9980e-01  5.8099e-01 -2.4414e-03]
#  [ 9.9989e+02  9.9957e+02  9.9997e+02 -7.9980e-01  5.8099e-01 -2.4414e-03]
#  ...
#  [ 1.0015e+03  9.8277e+02  1.0015e+03  4.5612e-01 -1.0858e-01  8.8287e-01]
#  [ 1.0015e+03  9.8307e+02  1.0015e+03  4.6405e-01 -1.0559e-01  8.7897e-01]
#  [ 1.0015e+03  9.8367e+02  1.0015e+03  4.6631e-01 -1.0394e-01  8.7769e-01]]
# /A14_A1/B560818162851
# B56 - Number of detected cp:  67
# B56 start 12590 B56
# [[ 9.9998e+02  9.9853e+02  1.0000e+03 -5.9833e-01  7.6410e-01 -1.6626e-01]
#  [ 1.0000e+03  9.9853e+02  9.9999e+02 -5.9833e-01  7.6410e-01 -1.6626e-01]
#  [ 9.9994e+02  9.9883e+02  9.9998e+02 -5.9833e-01  7.6410e-01 -1.6626e-01]
#  ...
#  [ 1.0009e+03  9.8013e+02  1.0005e+03  9.5581e-01  1.5552e-01 -2.0044e-01]
#  [ 1.0008e+03  9.7943e+02  1.0005e+03  9.5581e-01  1.5552e-01 -2.0044e-01]
#  [ 1.0008e+03  9.7983e+02  1.0005e+03  9.5581e-01  1.5552e-01 -2.0044e-01]]
# /A14_A1/B780818162912
# B78 - Number of detected cp:  79
# start 20360 B78
# [[ 9.9992e+02  9.9741e+02  9.9995e+02 -5.1636e-01  8.1891e-01 -1.1353e-02]
#  [ 9.9987e+02  9.9801e+02  9.9997e+02 -5.1636e-01  8.1891e-01 -1.1353e-02]
#  [ 9.9993e+02  9.9721e+02  9.9996e+02 -5.1636e-01  8.1891e-01 -1.1353e-02]
#  ...
#  [ 1.0008e+03  9.6651e+02  1.0014e+03 -5.1880e-03  6.7444e-02  2.6202e-01]
#  [ 1.0008e+03  9.6651e+02  1.0013e+03 -6.1035e-04  6.3171e-02  2.6025e-01]
#  [ 1.0007e+03  9.6581e+02  1.0013e+03 -6.1035e-04  6.3171e-02  2.6025e-01]]
# /A14_A1/B820818152908
# B82 - Number of detected cp:  61
# start 23020 B82
# [[ 1.0000e+03  9.9935e+02  1.0000e+03 -3.6438e-02 -1.2415e-01  1.9531e-03]
#  [ 1.0000e+03  9.9925e+02  1.0000e+03 -3.6438e-02 -1.2415e-01  1.9531e-03]
#  [ 1.0001e+03  9.9945e+02  1.0000e+03 -3.6438e-02 -1.2415e-01  1.9531e-03]
#  ...
#  [ 1.0010e+03  9.8355e+02  1.0016e+03 -3.6328e-01  5.8966e-01 -3.0231e-01]
#  [ 1.0011e+03  9.8355e+02  1.0016e+03 -3.6328e-01  5.8966e-01 -3.0231e-01]
#  [ 1.0011e+03  9.8365e+02  1.0017e+03 -3.6328e-01  5.8966e-01 -3.0231e-01]]
# /A14_A1/B840818162908
# B84 - Number of detected cp:  61
# start 26490 B84
# [[ 9.9991e+02  9.9978e+02  9.9987e+02 -9.0698e-02 -7.0068e-02 -1.9446e-01]
#  [ 9.9989e+02  9.9974e+02  9.9990e+02 -9.0698e-02 -7.0068e-02 -1.9446e-01]
#  [ 9.9994e+02  9.9981e+02  9.9990e+02 -9.0698e-02 -7.0068e-02 -1.9446e-01]
#  ...
#  [ 1.0076e+03  1.0088e+03  1.0097e+03  7.0374e-01 -4.6790e-01 -4.8822e-01]
#  [ 1.0077e+03  1.0087e+03  1.0101e+03  6.9250e-01 -4.6753e-01 -4.9780e-01]
#  [ 1.0074e+03  1.0085e+03  1.0100e+03  6.8427e-01 -4.6625e-01 -5.0488e-01]]
# /A14_A1/B850818162932
# B85 - Number of detected cp:  42
# start 26650 B85
# [[ 9.9991e+02  9.9891e+02  1.0001e+03 -1.2286e-01  3.9227e-01  0.0000e+00]
#  [ 9.9993e+02  9.9921e+02  1.0001e+03 -1.2286e-01  3.9227e-01  0.0000e+00]
#  [ 9.9987e+02  9.9971e+02  1.0000e+03 -1.2286e-01  3.9227e-01  0.0000e+00]
#  ...
#  [ 1.0015e+03  9.8781e+02  1.0027e+03  8.4210e-01 -5.3650e-01 -1.9958e-02]
#  [ 1.0014e+03  9.8791e+02  1.0027e+03  8.4210e-01 -5.3650e-01 -1.9958e-02]
#  [ 1.0015e+03  9.8761e+02  1.0026e+03  8.4210e-01 -5.3650e-01 -1.9958e-02]]

# %%
#A5
# %run B_series_functions.ipynb
file_list = [
'B140818144102.csv',
'B170818144158.csv',
'B560818144115.csv',
'B750818144132.csv',
'B790818144150.csv',
'B800818144146.csv',
'B820818134146.csv',
'B850818144158.csv',
'B860818144137.csv',
]

# incomplete transect B730818162848.csv'
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A5_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A5/"
model= "ar"
width = 100
jump = 10
dim = 5
sigma = 1.36
params = [0,1,2]
data_vis = "off"
bkps_vis = "off"#"on"

for i in range(len(file_list)):
    drifter_id = file_list[i][0:3]
    path = common_path + file_list[i]
    data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A5_A1/B140818144102
# B14 - Number of detected cp:  7
# /A5_A1/B170818144158
# B17 - Number of detected cp:  9
# /A5_A1/B560818144115
# B56 - Number of detected cp:  3
# /A5_A1/B750818144132
# B75 - Number of detected cp:  5
# /A5_A1/B790818144150
# B79 - Number of detected cp:  5
# /A5_A1/B800818144146
# B80 - Number of detected cp:  9
# /A5_A1/B820818134146
# B82 - Number of detected cp:  10
# /A5_A1/B850818144158
# B85 - Number of detected cp:  10
# /A5_A1/B860818144137
# B86 - Number of detected cp:  8

# %% [markdown]
# # A6

# %%
#A6
# %run B_series_functions.ipynb
file_list = ['B130818145050.csv','B330818145101.csv','B550818145016.csv','B650818145108.csv','B680818145111.csv','B730818145100.csv','B740818145120.csv','B780818145129.csv']
#'B780818145129.csv' looks ok but cp detected before deployment
# 'B840818145123.csv' lost but recovered way down
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A6_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A6/"


model= "ar"
width = 100
jump = 10
dim = 5
sigma = 1
params = [0,2]
data_vis = "off"
bkps_vis = "off"#"on"

for i in range(len(file_list)):
    drifter_id = file_list[i][0:3]
    path = common_path + file_list[i]
    data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A6_A1/B130818145050
# B13 - Number of detected cp:  13
# /A6_A1/B330818145101
# B33 - Number of detected cp:  15
# /A6_A1/B550818145016
# B55 - Number of detected cp:  11
# /A6_A1/B650818145108
# B65 - Number of detected cp:  12
# /A6_A1/B680818145111
# B68 - Number of detected cp:  12
# /A6_A1/B730818145100
# B73 - Number of detected cp:  13
# /A6_A1/B740818145120
# B74 - Number of detected cp:  14
# /A6_A1/B780818145129
# B78 - Number of detected cp:  18

# %% [markdown]
# # A7

# %%
#A7
# %run B_series_functions.ipynb
file_list_A7 =['B140818150819.csv','B170818150927.csv','B560818150827.csv','B680818150844.csv','B730818150836.csv','B780818150905.csv','B790818150923.csv','B820818140909.csv','B830818150926.csv']

#'B780818145129.csv' looks ok but cp detected before deployment
# 'B840818145123.csv' lost but recovered way down
common_path_A7 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A7_A1/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A7/"


model_A7= "ar"
width_A7 = 100
jump_A7 = 10
dim_A7 = 5
sigma_A7 = 1
params_A7 = [0,2,4]
data_vis = "on"
bkps_vis = "off"#"on"


for i in range(len(file_list_A7)):
    k = 1*i
    drifter_id = file_list_A7[i][0:3]
    path_A7 = common_path_A7 + file_list_A7[i]
    A7_data, A7_lp,A7_bkps, A7_lp_mean = cross_section_comp(path_A7,drifter_id,model_A7,width_A7,jump_A7,dim_A7,sigma_A7,params_A7,data_vis,bkps_vis,k)
    saved_data = pd.DataFrame(A7_lp_mean)        
    #saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A7_A1/B140818150819
# B14 - Number of detected cp:  10
# /A7_A1/B170818150927
# B17 - Number of detected cp:  15
# /A7_A1/B560818150827
# B56 - Number of detected cp:  21
# /A7_A1/B680818150844
# B68 - Number of detected cp:  22
# /A7_A1/B730818150836
# B73 - Number of detected cp:  22
# /A7_A1/B780818150905
# B78 - Number of detected cp:  23
# /A7_A1/B790818150923
# B79 - Number of detected cp:  19
# /A7_A1/B820818140909
# B82 - Number of detected cp:  17
# /A7_A1/B830818150926
# B83 - Number of detected cp:  21

# %% [markdown]
# # Cross sections A8-A1

# %%
# %run B_series_functions.ipynb
common_path_A8 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A8_A1/"

#cross_section_comp(filepath,name):
model_A8= "ar"#"rank"#"linear"
width_A8 = 100
jump_A8 = 10
dim_A8 = 2
sigma_A8 = 1.3
params_A8 = [0,1]#what drifter parameters to use
data_vis = "on"


# %run B_series_functions.ipynb
file_list_A8 = ['B100818151712.csv','B130818151711.csv','B330818151708.csv','B550818151622.csv','B650818151700.csv','B740818151658.csv','B750818151704.csv','B800818151707.csv','B840818151701.csv','B850818151721.csv','B860818151701.csv']
#'B830818161850.csv'garbage file
#'B140818162018.csv', incomplete

model_A8= "ar"
width_A8 = 100
jump_A8 = 10
dim_A8 = 5
sigma_A8 = 1
params_A8 = [0,2]
data_vis = "on"
bkps_vis = "off"#"on"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A8/"

for i in range(len(file_list_A8)):
    drifter_id = file_list_A8[i][0:3]
    path_A8 = common_path_A8 + file_list_A8[i]
    A8_data, A8_lp,A8_bkps,A8_lp_mean = cross_section_comp(path_A8,drifter_id,model_A8,width_A8,jump_A8,dim_A8,sigma_A8,params_A8,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(A8_lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A8_A1/B100818151712
# B10 - Number of detected cp:  26
# /A8_A1/B130818151711
# B13 - Number of detected cp:  26
# /A8_A1/B330818151708
# B33 - Number of detected cp:  26
# /A8_A1/B550818151622
# B55 - Number of detected cp:  24
# /A8_A1/B650818151700
# B65 - Number of detected cp:  34
# /A8_A1/B740818151658
# B74 - Number of detected cp:  24
# /A8_A1/B750818151704
# B75 - Number of detected cp:  21
# /A8_A1/B800818151707
# B80 - Number of detected cp:  24
# /A8_A1/B840818151701
# B84 - Number of detected cp:  26
# /A8_A1/B850818151721
# B85 - Number of detected cp:  20
# /A8_A1/B860818151701
# B86 - Number of detected cp:  20

# %% [markdown]
# # A9

# %%
def process_files_for_mp(file_list,common_path,save_path):
    model= "ar"
    width = 100
    jump = 10
    dim = 5
    sigma = 1
    params = [0,2]
    data_vis = "off"
    bkps_vis = "off"#"on"

    for i in range(len(file_list)):
        drifter_id = file_list[i][0:12]
        path = common_path + file_list[i]
        data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)

        saved_data = pd.DataFrame(lp_mean)        
        saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
    return lp_mean

# %%
#A9
# %run B_series_functions.ipynb
file_list = [
'\B100818152836.csv',
'\B130818152833.csv',
'\B170818152910.csv',
'\B330818152828.csv',
'\B750818152813.csv',
'\B780818152816.csv',
'\B790818152828.csv',
'\B840818152805.csv',
'\B850818152823.csv',
'\B860818152800.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A9/"


        
process_files_for_mp(file_list,common_path,save_path)

# %% [markdown]
# # A10

# %%
# %run B_series_functions.ipynb
file_list = [
'\B140818153746.csv',
'\B550818153704.csv',
'\B560818153732.csv',
'\B650818153743.csv',
'\B730818153727.csv',
'\B740818153745.csv',
'\B800818153749.csv',
'\B820818143747.csv',
'\B830818153759.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A10/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 140818153746
# B14 - Number of detected cp:  27
# 550818153704
# B55 - Number of detected cp:  53
# 560818153732
# B56 - Number of detected cp:  33
# 650818153743
# B65 - Number of detected cp:  24
# 730818153727
# B73 - Number of detected cp:  46
# 740818153745
# B74 - Number of detected cp:  19
# 800818153749
# B80 - Number of detected cp:  25
# 820818143747
# B82 - Number of detected cp:  38
# 830818153759
# B83 - Number of detected cp:  32

# %% [markdown]
# # A11

# %%
# %run B_series_functions.ipynb
file_list = [
'\B550818155026.csv',
'\B560818155107.csv',
'\B740818155126.csv',
'\B790818155150.csv',
'\B800818155147.csv',
'\B820818145151.csv',
'\B830818155203.csv',
'\B840818155159.csv',
'\B850818155219.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A11/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 550818155026
# B55 - Number of detected cp:  35
# 560818155107
# B56 - Number of detected cp:  25
# 740818155126
# B74 - Number of detected cp:  35
# 790818155150
# B79 - Number of detected cp:  1
# 800818155147
# B80 - Number of detected cp:  34
# 820818145151
# B82 - Number of detected cp:  26
# 830818155203
# B83 - Number of detected cp:  154
# 840818155159
# B84 - Number of detected cp:  1
# 850818155219
# B85 - Number of detected cp:  43

# %% [markdown]
# # A12

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818160001.csv',
'\B130818155958.csv',
'\B140818155949.csv',
'\B170818160039.csv',
'\B330818160007.csv',
'\B650818155958.csv',
'\B730818155945.csv',
'\B750818160007.csv',
'\B780818160012.csv',
'\B860818155949.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A12/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 100818160001
# B10 - Number of detected cp:  52
# 130818155958
# B13 - Number of detected cp:  12
# 140818155949
# B14 - Number of detected cp:  54
# 170818160039
# B17 - Number of detected cp:  47
# 330818160007
# B33 - Number of detected cp:  31
# 650818155958
# B65 - Number of detected cp:  29
# 730818155945
# B73 - Number of detected cp:  56
# 750818160007
# B75 - Number of detected cp:  32
# 780818160012
# B78 - Number of detected cp:  56
# 860818155949
# B86 - Number of detected cp:  27

# %% [markdown]
# # A15

# %%
# %run B_series_functions.ipynb
file_list_A15 = ['B330818171826.csv',
'B550818171746.csv',
'B680818171831.csv',
'B740818171835.csv',
'B800818171840.csv',
'B840818171835.csv',
'B850818171902.csv']

# incomplete transect B730818162848.csv'
common_path_A15 = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/cross_section_deployments/A15_A1/"
model_A15= "ar"
width_A15 = 100
jump_A15 = 10
dim_A15 = 5
sigma_A15 = 1.36
params_A15 = [0,1,2]
data_vis = "off"
bkps_vis = "off"#"on"


for i in range(len(file_list_A15)):
    k = 12*i
    drifter_id = file_list_A15[i][0:3]
    path_A15 = common_path_A15 + file_list_A15[i]
    A15_data, A15_lp,A15_bkps,A15_lp_mean = cross_section_comp(path_A15,drifter_id,model_A15,width_A15,jump_A15,dim_A15,sigma_A15,params_A15,data_vis,bkps_vis,k)
    start = A15_bkps[0]
    print("start",start,drifter_id)
    end = A15_bkps[-1]
    if bkps_vis == "on":
        #show ruptures breakpoints
        rpt.show.display(A15_data[:,params_A15], A15_bkps, figsize=(10, 6))
    if data_vis =="on":
        plt.subplot(len(file_list_A15),1,i+1)
        plt.plot(time_array(start,end),A15_lp_mean[start:end],label = drifter_id)#plot wit seconds on x axis
        #plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x
        plt.ylabel('Pressure []')
        #plt.plot(time_array(start,end),acc_abs[start:end]+k)

save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A15/"

for i in range(len(file_list_A15)):
    drifter_id = file_list_A15[i][0:3]
    path_A15 = common_path_A15 + file_list_A15[i]
    A15_data, A15_lp,A15_bkps,A15_lp_mean = cross_section_comp(path_A15,drifter_id,model_A15,width_A15,jump_A15,dim_A15,sigma_A15,params_A15,data_vis,bkps_vis,k)
    
    saved_data = pd.DataFrame(A15_lp_mean)        
    saved_data.to_csv(save_path+drifter_id+".csv",header = "pressure")
# Out:
# /A15_A1/B330818171826
# B33081817182 - Number of detected cp:  80
# start 8030 B33081817182
# /A15_A1/B550818171746
# B55081817174 - Number of detected cp:  63
# start 10110 B55081817174
# /A15_A1/B680818171831
# B68081817183 - Number of detected cp:  67
# start 14600 B68081817183
# /A15_A1/B740818171835
# B74081817183 - Number of detected cp:  82
# start 16690 B74081817183
# /A15_A1/B800818171840
# B80081817184 - Number of detected cp:  36
# start 19460 B80081817184
# /A15_A1/B840818171835
# B84081817183 - Number of detected cp:  93
# start 22440 B84081817183
# /A15_A1/B850818171902
# B85081817190 - Number of detected cp:  38
# start 23410 B85081817190
# /A15_A1/B330818171826
# B33 - Number of detected cp:  80
# /A15_A1/B550818171746
# B55 - Number of detected cp:  63
# /A15_A1/B680818171831
# B68 - Number of detected cp:  67
# /A15_A1/B740818171835
# B74 - Number of detected cp:  82
# /A15_A1/B800818171840
# B80 - Number of detected cp:  36
# /A15_A1/B840818171835
# B84 - Number of detected cp:  93
# /A15_A1/B850818171902
# B85 - Number of detected cp:  38

# %% [markdown]
# # A16

# %%
# %run B_series_functions.ipynb
file_list = [
'\B130818173609.csv',
'\B170818173648.csv',
'\B330818173613.csv',
'\B550818173533.csv',
'\B560818173635.csv',
'\B740818173622.csv',
'\B800818173629.csv',
'\B840818173633.csv',
'\B850818173653.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A16/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 130818173609
# B13 - Number of detected cp:  41
# 170818173648
# B17 - Number of detected cp:  1
# 330818173613
# B33 - Number of detected cp:  39
# 550818173533
# B55 - Number of detected cp:  110
# 560818173635
# B56 - Number of detected cp:  1
# 740818173622
# B74 - Number of detected cp:  73
# 800818173629
# B80 - Number of detected cp:  23
# 840818173633
# B84 - Number of detected cp:  84
# 850818173653
# B85 - Number of detected cp:  105

# %% [markdown]
# # A17

# %%
# %run B_series_functions.ipynb
file_list = [
'\B140818174809.csv',
'\B650818174819.csv',
'\B730818174804.csv',
'\B750818174827.csv',
'\B780818174833.csv',
'\B820818164832.csv',
'\B830818174844.csv',
'\B860818174821.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A17/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 140818174809
# B14 - Number of detected cp:  1
# 650818174819
# B65 - Number of detected cp:  3
# 730818174804
# B73 - Number of detected cp:  96
# 750818174827
# B75 - Number of detected cp:  3
# 780818174833
# B78 - Number of detected cp:  71
# 820818164832
# B82 - Number of detected cp:  109
# 830818174844
# B83 - Number of detected cp:  85
# 860818174821
# B86 - Number of detected cp:  1

# %% [markdown]
# # A18

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818183717.csv',
'\B140818183733.csv',
'\B330818183818.csv',
'\B730818183818.csv',
'\B740818183906.csv',
'\B750818183941.csv',
'\B780818184018.csv',
'\B170818184221.csv',
'\B820818165611.csv',
'\B830818184200.csv',
'\B860818184147.csv',
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A18/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 100818183717
# B10 - Number of detected cp:  100
# 140818183733
# B14 - Number of detected cp:  1
# 330818183818
# B33 - Number of detected cp:  114
# 730818183818
# B73 - Number of detected cp:  75
# 740818183906
# B74 - Number of detected cp:  91
# 750818183941
# B75 - Number of detected cp:  60
# 780818184018
# B78 - Number of detected cp:  12
# 170818184221
# B17 - Number of detected cp:  121
# 820818165611
# B82 - Number of detected cp:  1
# 830818184200
# B83 - Number of detected cp:  62
# 860818184147
# B86 - Number of detected cp:  26

# %% [markdown]
# # A20

# %%
# %run B_series_functions.ipynb
file_list = [
'\B130818185922.csv',
'\B150818185905.csv',
'\B550818185839.csv',
'\B650818185921.csv',
'\B800818185927.csv',
'\B840818185919.csv',
'\B850818185936.csv',
]
#'\B560818185908.csv',
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A20/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 130818185922
# B13 - Number of detected cp:  127
# 150818185905
# B15 - Number of detected cp:  64
# 550818185839
# B55 - Number of detected cp:  80
# 650818185921
# B65 - Number of detected cp:  32
# 800818185927
# B80 - Number of detected cp:  52
# 840818185919
# B84 - Number of detected cp:  3
# 850818185936
# B85 - Number of detected cp:  116
# array([ 999.9991059 ,  999.99569041,  999.99218544, ..., 1004.75868441,
#        1004.75732931, 1004.75601311])

# %% [markdown]
# # A25

# %%
# %run B_series_functions.ipynb
file_list = [
'\B100818134757.csv',
'\B330818134755.csv',
'\B550818134710.csv',
'\B560818134740.csv',
'\B650818134756.csv',
'\B730818134747.csv',
'\B740818134809.csv',
'\B750818134821.csv',
'\B790818134839.csv',
'\B800818134833.csv',
'\B830818134842.csv',
'\B840818134834.csv',
'\B860818134827.csv',
]

#'\B560818185908.csv',
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/All_csv_files_18082020/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/2020/processed_drifter_data/A25/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 100818134757
# \B1008181347 - Number of detected cp:  92
# 330818134755
# \B3308181347 - Number of detected cp:  197
# 550818134710
# \B5508181347 - Number of detected cp:  41
# 560818134740
# \B5608181347 - Number of detected cp:  74
# 650818134756
# \B6508181347 - Number of detected cp:  41
# 730818134747
# \B7308181347 - Number of detected cp:  129
# 740818134809
# \B7408181348 - Number of detected cp:  21
# 750818134821
# \B7508181348 - Number of detected cp:  7
# 790818134839
# \B7908181348 - Number of detected cp:  1
# 800818134833
# \B8008181348 - Number of detected cp:  1
# 830818134842
# \B8308181348 - Number of detected cp:  323
# 840818134834
# \B8408181348 - Number of detected cp:  3
# 860818134827
# \B8608181348 - Number of detected cp:  2
# array([1000.02192482, 1000.01445403, 1000.00710923, ...,  999.40145334,
#         999.40828123,  999.41498728])

# %% [markdown]
# # Load data from other days 2020

# %%
"""15.08.2020 A25 Deployments"""

B080815185830.txt
B680815190017.txt
B170815190312.txt
B840815190427.txt
B100815190650.txt
B830815190811.txt
B330815191035.txt
B080815201322.txt
B100815201315.txt
B170815201430.txt
B330815201357.txt
B680815201348.txt
B830815201405.txt
B840815201357.txt
B080815205152.txt
B100815210659.txt
B170815205235.txt
B680815205133.txt
B830815205120.txt
B840815205106.txt
B080815215122.txt
B100815215110.txt
B170815215144.txt
B830815215113.txt

# %% [markdown]
# # Load 2021 data
# Load bseries data from the 2021 channel

# %%
# %run B_series_functions.ipynb
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial channel/13072021/All_Bseries_2021_1307/"
file_list = [
"B850713180305.csv",
"B100713154414.csv",
"B130713165653.csv",
"B150101000000.csv",
"B150602153853.csv",
"B150602161337.csv",
"B150602161415.csv",
"B550713165700.csv",
"B550713180228.csv",
"B731206160254.csv",
"B731206160416.csv",
"B750713165722.csv",
"B750713180252.csv",
"B800713165727.csv",
"B800713180257.csv",
"B850713165747.csv",
]

common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/All_Bseries_2021_1307/"
save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 13072021/All_Bseries_2021_1307/B850713180305
# B85071318030 - Number of detected cp:  45
# 13072021/All_Bseries_2021_1307/B100713154414
# B10071315441 - Number of detected cp:  2
# 13072021/All_Bseries_2021_1307/B130713165653
# B13071316565 - Number of detected cp:  118
# 13072021/All_Bseries_2021_1307/B150101000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_815/3863112978.py in <module>
#      22 common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/All_Bseries_2021_1307/"
#      23 save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
# ---> 24 process_files_for_mp(file_list,common_path,save_path)
#
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_815/624234578.py in process_files_for_mp(file_list, common_path, save_path)
#      12         drifter_id = file_list[i][0:12]
#      13         path = common_path + file_list[i]
# ---> 14         data, lp,bkps,lp_mean = cross_section_comp(path,drifter_id,model,width,jump,dim,sigma,params,data_vis,bkps_vis,k)
#      15
#      16         saved_data = pd.DataFrame(lp_mean)
#
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_815/3569703785.py in cross_section_comp(filepath, name, model, width, jump, dim, sigma, params, data_vis, bkps_vis, k)
#     127     acc_abs = np.sqrt(data_low_pass[:,3]**2 + data_low_pass[:,4]**2 + data_low_pass[:,5]**2)
#     128
# --> 129     data_bkps = window_cpd(data[:,params],model,width,jump,dim,sigma)
#     130     print(name,"- Number of detected cp: ",len(data_bkps))
#     131     """if bkps_vis == "on":
#
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_815/3569703785.py in window_cpd(signal, model, width, jump, dim, sigma)
#      49     n = np.shape(signal)[0]
#      50
# ---> 51     algo = rpt.Window(model=model, width = width, jump = jump).fit(signal)
#      52     my_bkps = algo.predict(pen=np.log(n) * dim *sigma ** 2)
#      53
#
# ~/opt/anaconda3/envs/master_env/lib/python3.8/site-packages/ruptures/detection/window.py in fit(self, signal)
#     130         for k in self.inds:
#     131             start, end = k - self.width // 2, k + self.width // 2
# --> 132             gain = self.cost.error(start, end)
#     133             if np.isinf(gain) and gain < 0:
#     134                 # segment is constant and no improvment possible on start .. end
#
# ~/opt/anaconda3/envs/master_env/lib/python3.8/site-packages/ruptures/costs/costautoregressive.py in error(self, start, end)
#      69             raise NotEnoughPoints
#      70         y, X = self.signal[start:end], self.covar[start:end]
# ---> 71         _, residual, _, _ = lstsq(X, y, rcond=None)
#      72         return residual.sum()
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~/opt/anaconda3/envs/master_env/lib/python3.8/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2304         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2305         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2306     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2307     if m == 0:
#    2308         x[...] = 0
#
# KeyboardInterrupt:

# %%
#Load cave deployment

# %run B_series_functions.ipynb
common_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Kongsvegen_cave/08062021/"
file_list = [
"\B840608200152.csv"
]

save_path = "/Users/georgecowie/Documents/Master/Masteroppgave/data/Drifters/Supraglacial_channel/13072021/processed_for_mp/"
process_files_for_mp(file_list,common_path,save_path)
# Out:
# 021/\B840608200152
# \B8406082001 - Number of detected cp:  45
# array([999.90492284, 999.91016037, 999.91517395, ..., 162.87374984,
#        169.35807039, 175.36217796])

# %% [markdown]
# # DBA
# https://github.com/fpetitjean/DBA

# %% [markdown]
# # Dynamic time warping

# %%
# %run B_series_functions.ipynb 

def dtw_drifters(s1,s2):
    #d, path = dtw.warping_path(s1, s2, window=20, use_pruning=True )
    #best_path = dtw.best_path(paths)
    #dtwvis.plot_warpingpaths(s1, s2, paths, best_path)

    #path = dtw.warping_path(s1, s2,window = 100)
    path = dtw.warping_path(s1, s2)


    dtwvis.plot_warping(s1, s2, path)
    distance = dtw.distance(s1, s2)
    print("Distance = ",distance)

s1 = A14_all[1][0:-29000:10]#A14_df.iloc[0:-159000:10,1].dropna().to_numpy()
s2 = A14_all[2][0:-23500:10]#A14_df.iloc[0:-116500:10,2].dropna().to_numpy()

s3 = A6_all[1][0:-17350:10]
s4 = A6_all[2][0:-14100:10]


#s3 = A14_df.iloc[0:58300:10,1].dropna().to_numpy()
#4 = A14_df.iloc[0:100800:10,2].dropna().to_numpy()

#plt.plot(A14_lp_mean[start:end],label = drifter_id)#plot with index on x


dtw_drifters(s1,s2)
dtw_drifters(s3,s4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_k/bgs9c7fx4098w4vgtc325b8w0000gn/T/ipykernel_3637/153524178.py in <module>
#      14     print("Distance = ",distance)
#      15
# ---> 16 s1 = A14_all[1][0:-29000:10]#A14_df.iloc[0:-159000:10,1].dropna().to_numpy()
#      17 s2 = A14_all[2][0:-23500:10]#A14_df.iloc[0:-116500:10,2].dropna().to_numpy()
#      18
#
# NameError: name 'A14_all' is not defined
